# %% [markdown]
# # IMPORT THƯ VIỆN

# %%
import logging
import json
from typing import List, Dict, Optional
import re
from collections import Counter
import pandas as pd

# %% [markdown]
# # LOGGER

# %%
def _setup_logger(name: str, level=logging.INFO, log_file=None) -> logging.Logger:
    '''
         Hàm khởi tạo và trả về logger đã cấu hình
    '''
    formatter = logging.Formatter('<%(levelname)s-%(name)s> - %(message)s')

    handler = logging.StreamHandler()
    handler.setFormatter(formatter)

    logger = logging.getLogger(name)
    logger.setLevel(level)

    # Tránh nhân bản handler
    if not logger.handlers:
        logger.addHandler(handler)

        # Nếu muốn ghi vào file log
        if log_file:
            file_handler = logging.FileHandler(log_file)
            file_handler.setFormatter(formatter)
            logger.addHandler(file_handler)

    return logger

# %%
logger_level = logging.DEBUG

# %% [markdown]
# # UTILS

# %%
utils_logger = _setup_logger("Utils", logger_level)

class Utils:
    @staticmethod
    def load_json(file_path: str) -> dict:
        """Đọc file .json và trả về dữ liệu dưới dạng dict hoặc list."""
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                utils_logger.debug(f"Load FILE JSON {file_path} thành công")
                return data
        except Exception as e:
            utils_logger.debug(f"Load FILE JSON {file_path} thất bại")
            raise Exception(e)

    @staticmethod
    def load_jsonl(file_path: str) -> List[Dict]:
        """Đọc file .jsonl và trả về list chứa các dict (mỗi dòng là một JSON).
    
        Args:
            file_path (str): Đường dẫn tới file .jsonl
            utils_logger: Logger đã được cấu hình sẵn (thường dùng logging.getLogger(...))
    
        Returns:
            List[Dict]: Danh sách các dòng JSON đã parse thành dict
        """
        data = []
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                for line_num, line in enumerate(f, start=1):
                    line = line.strip()
                    if line:
                        try:
                            data.append(json.loads(line))
                        except json.JSONDecodeError as e:
                            utils_logger.debug(f"Lỗi JSON ở dòng {line_num}: {e}")
        except FileNotFoundError:
            utils_logger.debug(f"Không tìm thấy file: {file_path}")
        except Exception as e:
            utils_logger.debug(f"Lỗi khi đọc file '{file_path}': {e}")
        return data

    @staticmethod
    def write_csv(data: List[Dict], file_path: str, encoding: str = "utf-8", index: bool = False) -> None:
        """
        Ghi list[dict] hoặc pandas.DataFrame ra file CSV.
    
        Args:
            data (List[Dict] or pd.DataFrame): Dữ liệu cần ghi.
            file_path (str): Đường dẫn file CSV đầu ra.
            encoding (str): Kiểu mã hóa (mặc định: "utf-8").
            index (bool): Có ghi chỉ số dòng (index) hay không (mặc định: False).
        """
        try:
            if isinstance(data, pd.DataFrame):
                df = data
            else:
                df = pd.DataFrame(data)
    
            df.to_csv(file_path, index=index, encoding=encoding)
            utils_logger.debug(f"[write_csv] ✅ Đã ghi {len(df)} dòng vào '{file_path}'")
    
        except Exception as e:
            utils_logger.debug(f"[write_csv] ❌ Lỗi khi ghi CSV: {e}")

# %% [markdown]
# # POST ENTITY

# %%
entity_logger = _setup_logger("Entity", logger_level)

# %%
class CommentReactionsInfo:
    def __init__(self, reaction_data: Dict):
        self.total = reaction_data.get("total", 0)
        self.detail = reaction_data.get("detail", {}) or {}
        self.reaction_key_map = {
            k.lower(): k for k in self.detail.keys()
        }

    def get_total(self) -> int:
        return self.total

    def get_count(self, reaction: str) -> int:
        key = self.reaction_key_map.get(reaction.lower())
        if key is None:
            entity_logger.debug(f"[CommentReactionsInfo] '{reaction}' không tồn tại trong reaction_key_map")
            return 0
        return self.detail.get(key, 0)

    def get_percentage(self, reaction: str) -> float:
        count = self.get_count(reaction)
        return (count / self.total) * 100 if self.total > 0 else 0.0

    def get_all_counts(self) -> Dict[str, int]:
        return dict(self.detail)

    def get_all_percentages(self) -> Dict[str, float]:
        return {
            k: round((v / self.total) * 100, 2) if self.total > 0 else 0.0
            for k, v in self.detail.items()
        }

    def most_common(self, top_n: int = 2) -> List[tuple]:
        return sorted(self.detail.items(), key=lambda x: x[1], reverse=True)[:top_n]

    def get_available_reactions(self) -> List[str]:
        return list(self.detail.keys())

# %%
class ParentComment:
    def __init__(self, data: Dict):
        self.text = data.get("text", "")
        self.reactions_raw = data.get("reactions", {})
        self.raw = data

        entity_logger.debug(f"[ParentComment] Init | Length: {self.length()}")

    def get_text(self) -> str:
        return self.text

    def has_link(self) -> bool:
        has = "http" in self.text
        entity_logger.debug(f"[ParentComment] has_link: {has}")
        return has

    def length(self) -> int:
        return len(self.text)

    def get_keywords(self) -> List[str]:
        words = re.findall(r'\w+', self.text.lower())
        entity_logger.debug(f"[ParentComment] {len(words)} keywords")
        return words

    def get_reactions_info(self) -> CommentReactionsInfo:
        entity_logger.debug("[ParentComment] get_reactions_info")
        return CommentReactionsInfo(self.reactions_raw)

    def get_reaction_count(self) -> int:
        info = self.get_reactions_info()
        return info.get_total()

    def to_dict(self) -> Dict:
        return {
            "text": self.text,
            "reaction_count": self.get_reaction_count(),
            "has_link": self.has_link(),
            "length": self.length(),
        }

# %%
class ReactionsInfo:
    def __init__(self, reaction_dict: Dict[str, int]):
        self.reactions = reaction_dict or {}
        self.total = sum(self.reactions.values())       

    def get_total(self) -> int:
        return self.total

    def get_count(self, reaction: str) -> int:
        """Trả về số lượng reaction theo tên không phân biệt hoa thường"""
        key = reaction
        if key is None:
            entity_logger.debug(f"[get_count] '{reaction}' không tồn tại trong reaction_key_map")
            return 0
        return self.reactions.get(key, 0)

    def get_percentage(self, reaction: str) -> float:
        count = self.get_count(reaction)
        return (count / self.total) * 100 if self.total > 0 else 0.0

    def get_all_counts(self) -> Dict[str, int]:
        return dict(self.reactions)

    def get_all_percentages(self) -> Dict[str, float]:
        return {
            k: round((v / self.total) * 100, 2) if self.total > 0 else 0.0
            for k, v in self.reactions.items()
        }

    def most_common(self, top_n: int = 3) -> List[tuple]:
        return sorted(self.reactions.items(), key=lambda x: x[1], reverse=True)[:top_n]

    def get_available_reactions(self) -> List[str]:
        """Trả về danh sách các loại cảm xúc có mặt trong post"""
        return list(self.reactions.keys())

# %%
class FacebookPost:
    def __init__(self, data: Dict):
        entity_logger.debug("[FacebookPost] Initializing...")
        self.data = data
        
        raw_comments = data.get("comments", {}).get("comments", [])
        entity_logger.debug(f"[FacebookPost] Found {len(raw_comments)} parent comments.")
        self.parent_comments: List[ParentComment] = [
            ParentComment(c) for c in raw_comments
        ]

    def get_creation_time(self) -> Optional[str]:
        ts = self.data.get("creation_time")
        if ts:
            try:
                dt = datetime.utcfromtimestamp(ts)
                formatted = dt.strftime('%Y-%m-%d %H:%M:%S UTC')
                entity_logger.debug(f"[get_creation_time] Formatted time: {formatted}")
                return formatted
            except Exception as e:
                entity_logger.debug(f"[get_creation_time] Error formatting timestamp: {e}")
        return None

    def get_reactions_info(self) -> ReactionsInfo:
        reaction_data = self.data.get("reactions_detail", {})
        entity_logger.debug(f"[get_reactions_info] Raw: {reaction_data}")
        return ReactionsInfo(reaction_data)

    def get_post_text(self) -> str:
        text = self.data.get("post_content", "")
        entity_logger.debug(f"[get_post_text] Length: {len(text)}")
        return text

    def get_post_url(self) -> str:
        return self.data.get("post_url", "")

    def get_total_reactions(self) -> int:
        total = self.data.get("total_reactions", 0)
        entity_logger.debug(f"[get_total_reactions] Total: {total}")
        return total

    def get_reaction_breakdown(self) -> Dict[str, int]:
        reactions = self.data.get("reactions_detail", {})
        entity_logger.debug(f"[get_reaction_breakdown] Reactions: {reactions}")
        return reactions

    def get_comment_count(self) -> int:
        count = self.data.get("comment_count", 0)
        entity_logger.debug(f"[get_comment_count] Total: {count}")
        return count

    def get_share_count(self) -> int:
        try:
            share_count = int(self.data.get("share_count", "0"))
        except ValueError:
            share_count = 0
        entity_logger.debug(f"[get_share_count] Share count: {share_count}")
        return share_count

    def get_parent_comments(self) -> List[ParentComment]:
        entity_logger.debug(f"[get_parent_comments] {len(self.parent_comments)} bình luận cha")
        return self.parent_comments

    def get_average_comment_length(self) -> float:
        if not self.parent_comments:
            return 0.0
        lengths = [c.length() for c in self.parent_comments]
        avg = sum(lengths) / len(lengths)
        entity_logger.debug(f"[get_average_comment_length] Trung bình: {avg}")
        return avg

    def get_link_comments(self) -> List[ParentComment]:
        linked = [c for c in self.parent_comments if c.has_link()]
        entity_logger.debug(f"[get_link_comments] Có {len(linked)} bình luận chứa link")
        return linked

    def get_top_keywords_in_comments(self, top_n: int = 10) -> List[tuple]:
        counter = Counter()
        for c in self.parent_comments:
            counter.update(c.get_keywords())
        result = counter.most_common(top_n)
        entity_logger.debug(f"[get_top_keywords_in_comments] Top {top_n}: {result}")
        return result

    def get_first_comment_with_link(self) -> Optional[ParentComment]:
        for c in self.parent_comments:
            if c.has_link():
                entity_logger.debug("[get_first_comment_with_link] Tìm thấy bình luận có link")
                return c
        entity_logger.debug("[get_first_comment_with_link] Không có bình luận nào chứa link")
        return None

# %% [markdown]
# # PREPARE DATA

# %%
prepare_logger = _setup_logger("PrepareData", logger_level)

# %%
class PrepareData:
    @staticmethod
    def prepare_text_each_post(post: FacebookPost, max_comment: int = 50) -> List[str]:
        """
        Thực hiện các bước:
        Bước 1: Lấy nội dung bài post (post content)
        Bước 2: Lấy danh sách parent comment và nội dung từng comment
        Bước 3: Với mỗi comment, ghép nội dung post + comment thành một chuỗi → trả về list
        """
        # Bước 1: lấy nội dung post
        post_text = post.get_post_text().strip()
        prepare_logger.debug(f"[Bước 1] Post content: '{post_text[:80]}...' (length: {len(post_text)})")

        # Bước 2: lấy comment cha
        parent_comments = post.get_parent_comments()
        prepare_logger.debug(f"[Bước 2] Số lượng comment cha: {len(parent_comments)}")

        comment_texts = []
        n_comment = len(parent_comments)
        top_k_cmt = min(n_comment, max_comment)
        for i, c in enumerate(parent_comments[:top_k_cmt]):
            text = c.get_text().strip()
            if text:
                comment_texts.append(text)
                prepare_logger.debug(f"  - Comment #{i+1} | length: {len(text)} | preview: '{text[:60]}...'")

        # Bước 3: ghép post + comment
        merged_texts = [f"{post_text}\n\n{comment}" for comment in comment_texts]
        prepare_logger.debug(f"[Bước 3] Tổng số mẫu ghép: {len(merged_texts)}")

        return merged_texts

    @staticmethod
    def prepare_corpus_content_df(posts: List[FacebookPost], max_comment: int = 50) -> pd.DataFrame:
        """
        Trả về DataFrame gồm 2 cột: 'content' và 'post_id'
        - 'content': văn bản sau khi merge post content + comment content
        - 'post_id': lấy từ 'feedback_id' trong dict gốc
        """
        prepare_logger.debug(f"[prepare_corpus_content_df] Xử lý {len(posts)} bài viết | Max Comment: {max_comment}")
    
        records = []
    
        for i, post in enumerate(posts):
            try:
                prepare_logger.debug(f"[Post {i+1}] Đang xử lý post")
                post_id = i + 1
                merged_texts = PrepareData.prepare_text_each_post(post, max_comment)
    
                for content in merged_texts:
                    records.append({
                        "post_id": post_id,
                        "content": content
                    })
    
                prepare_logger.debug(f"[Post {i+1}] Thêm {len(merged_texts)} dòng vào DataFrame")
    
            except Exception as e:
                prepare_logger.debug(f"[Post {i+1}] Lỗi: {e}")
    
        df = pd.DataFrame(records)
        prepare_logger.debug(f"[prepare_corpus_content_df] Tổng số dòng: {len(df)}")
        return df

# %% [markdown]
# # MAIN

# %% [markdown]
# ## Load Posts

# %%
logger = _setup_logger("Main", logger_level)

# %%
post_file = "/kaggle/input/the-anh-post/posts_Theanh28.json"
posts_list = Utils.load_json(post_file)
logger.debug(f"Length post: {len(posts_list)}")
# Out:
# <DEBUG-Utils> - Load FILE JSON /kaggle/input/the-anh-post/posts_Theanh28.json thành công
# <DEBUG-Main> - Length post: 135

# %%
posts_entity = [FacebookPost(p) for p in posts_list]
logger.debug(len(posts_entity))
# Out:
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 196
# <DEBUG-Entity> - [ParentComment] Init | Length: 99
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 82
# <DEBUG-Entity> - [ParentComment] Init | Length: 66
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 233
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 86
# <DEBUG-Entity> - [ParentComment] Init | Length: 109
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 477
# <DEBUG-Entity> - [ParentComment] Init | Length: 157
# <DEBUG-Entity> - [ParentComment] Init | Length: 68
# <DEBUG-Entity> - [ParentComment] Init | Length: 92
# <DEBUG-Entity> - [ParentComment] Init | Length: 4
# <DEBUG-Entity> - [ParentComment] Init | Length: 99
# <DEBUG-Entity> - [ParentComment] Init | Length: 68
# <DEBUG-Entity> - [ParentComment] Init | Length: 80
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 392
# <DEBUG-Entity> - [ParentComment] Init | Length: 247
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 91
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 90
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 29 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 128
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 141
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 154
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 96
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 1317
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 130
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 285
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 141
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 148
# <DEBUG-Entity> - [ParentComment] Init | Length: 96
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 108
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 93
# <DEBUG-Entity> - [ParentComment] Init | Length: 240
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 77
# <DEBUG-Entity> - [ParentComment] Init | Length: 67
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 238
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 229
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 229
# <DEBUG-Entity> - [ParentComment] Init | Length: 90
# <DEBUG-Entity> - [ParentComment] Init | Length: 409
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 155
# <DEBUG-Entity> - [ParentComment] Init | Length: 134
# <DEBUG-Entity> - [ParentComment] Init | Length: 115
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 513
# <DEBUG-Entity> - [ParentComment] Init | Length: 112
# <DEBUG-Entity> - [ParentComment] Init | Length: 79
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 219
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 88
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 117
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 108
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 22 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 79
# <DEBUG-Entity> - [ParentComment] Init | Length: 79
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 83
# <DEBUG-Entity> - [ParentComment] Init | Length: 67
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 5 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 185
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 1
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 15 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 172
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 8 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 117
# <DEBUG-Entity> - [ParentComment] Init | Length: 188
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 101
# <DEBUG-Entity> - [ParentComment] Init | Length: 106
# <DEBUG-Entity> - [ParentComment] Init | Length: 1338
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 18 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 157
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 84
# <DEBUG-Entity> - [ParentComment] Init | Length: 3
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 9 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 199
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 4
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 8 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 0 parent comments.
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 1 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 756
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 1 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 1953
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 5 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 86
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 94
# <DEBUG-Entity> - [ParentComment] Init | Length: 100
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 167
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 3
# <DEBUG-Entity> - [ParentComment] Init | Length: 179
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 66
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 447
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 2 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 101
# <DEBUG-Entity> - [ParentComment] Init | Length: 89
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 76
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 79
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 92
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 81
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 1552
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 99
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 111
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 11 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 190
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 80
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 91
# <DEBUG-Entity> - [ParentComment] Init | Length: 110
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 125
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 85
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 95
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 120
# <DEBUG-Entity> - [ParentComment] Init | Length: 105
# <DEBUG-Entity> - [ParentComment] Init | Length: 85
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 74
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 178
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 82
# <DEBUG-Entity> - [ParentComment] Init | Length: 234
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 171
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 4
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 26 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 1641
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 80
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 2
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 238
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 75
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 183
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 116
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 66
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 91
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 109
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 160
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 87
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 26 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 217
# <DEBUG-Entity> - [ParentComment] Init | Length: 290
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 76
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 74
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 139
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 1 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 638
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 608
# <DEBUG-Entity> - [ParentComment] Init | Length: 261
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 309
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 253
# <DEBUG-Entity> - [ParentComment] Init | Length: 67
# <DEBUG-Entity> - [ParentComment] Init | Length: 101
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 54
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 114
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 232
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 174
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 236
# <DEBUG-Entity> - [ParentComment] Init | Length: 737
# <DEBUG-Entity> - [ParentComment] Init | Length: 124
# <DEBUG-Entity> - [ParentComment] Init | Length: 255
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 81
# <DEBUG-Entity> - [ParentComment] Init | Length: 151
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 74
# <DEBUG-Entity> - [ParentComment] Init | Length: 503
# <DEBUG-Entity> - [ParentComment] Init | Length: 124
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 114
# <DEBUG-Entity> - [ParentComment] Init | Length: 93
# <DEBUG-Entity> - [ParentComment] Init | Length: 91
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 130
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 129
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 415
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 162
# <DEBUG-Entity> - [ParentComment] Init | Length: 356
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 90
# <DEBUG-Entity> - [ParentComment] Init | Length: 554
# <DEBUG-Entity> - [ParentComment] Init | Length: 171
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 127
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 117
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 254
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 203
# <DEBUG-Entity> - [ParentComment] Init | Length: 76
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 96
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 68
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 93
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 100
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 84
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 133
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 85
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 14 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 92
# <DEBUG-Entity> - [ParentComment] Init | Length: 188
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 283
# <DEBUG-Entity> - [ParentComment] Init | Length: 73
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 83
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 924
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [ParentComment] Init | Length: 6
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 57
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 83
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# ...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 200
# <DEBUG-Entity> - [ParentComment] Init | Length: 234
# <DEBUG-Entity> - [ParentComment] Init | Length: 261
# <DEBUG-Entity> - [ParentComment] Init | Length: 76
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Entity> - [ParentComment] Init | Length: 79
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 117
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 126
# <DEBUG-Entity> - [ParentComment] Init | Length: 110
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 86
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 381
# <DEBUG-Entity> - [ParentComment] Init | Length: 393
# <DEBUG-Entity> - [ParentComment] Init | Length: 83
# <DEBUG-Entity> - [ParentComment] Init | Length: 3
# <DEBUG-Entity> - [ParentComment] Init | Length: 393
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 119
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 83
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 105
# <DEBUG-Entity> - [ParentComment] Init | Length: 168
# <DEBUG-Entity> - [ParentComment] Init | Length: 130
# <DEBUG-Entity> - [ParentComment] Init | Length: 69
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 34 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 76
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 82
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 0
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 148
# <DEBUG-Entity> - [ParentComment] Init | Length: 84
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 29
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 158
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 17 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 163
# <DEBUG-Entity> - [ParentComment] Init | Length: 87
# <DEBUG-Entity> - [ParentComment] Init | Length: 194
# <DEBUG-Entity> - [ParentComment] Init | Length: 3
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 124
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 147
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 143
# <DEBUG-Entity> - [ParentComment] Init | Length: 78
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 346
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 155
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 142
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 8
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 23
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 59
# <DEBUG-Entity> - [ParentComment] Init | Length: 26
# <DEBUG-Entity> - [ParentComment] Init | Length: 189
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 7
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 464
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 21
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 105
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 61
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [ParentComment] Init | Length: 156
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 51
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 127
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 63
# <DEBUG-Entity> - [ParentComment] Init | Length: 133
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 2
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 60
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 106
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 90
# <DEBUG-Entity> - [ParentComment] Init | Length: 34
# <DEBUG-Entity> - [ParentComment] Init | Length: 83
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 81
# <DEBUG-Entity> - [ParentComment] Init | Length: 179
# <DEBUG-Entity> - [ParentComment] Init | Length: 42
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 72
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 124
# <DEBUG-Entity> - [ParentComment] Init | Length: 95
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 62
# <DEBUG-Entity> - [ParentComment] Init | Length: 143
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 40
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 99
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 70
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 109
# <DEBUG-Entity> - [ParentComment] Init | Length: 14
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 124
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 19
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 3 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 21 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 157
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 92
# <DEBUG-Entity> - [ParentComment] Init | Length: 183
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 167
# <DEBUG-Entity> - [ParentComment] Init | Length: 48
# <DEBUG-Entity> - [ParentComment] Init | Length: 81
# <DEBUG-Entity> - [ParentComment] Init | Length: 58
# <DEBUG-Entity> - [ParentComment] Init | Length: 39
# <DEBUG-Entity> - [ParentComment] Init | Length: 1
# <DEBUG-Entity> - [ParentComment] Init | Length: 173
# <DEBUG-Entity> - [ParentComment] Init | Length: 33
# <DEBUG-Entity> - [ParentComment] Init | Length: 43
# <DEBUG-Entity> - [ParentComment] Init | Length: 81
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 16
# <DEBUG-Entity> - [ParentComment] Init | Length: 3
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 105
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 1 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 3249
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 0 parent comments.
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 13 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 169
# <DEBUG-Entity> - [ParentComment] Init | Length: 53
# <DEBUG-Entity> - [ParentComment] Init | Length: 56
# <DEBUG-Entity> - [ParentComment] Init | Length: 44
# <DEBUG-Entity> - [ParentComment] Init | Length: 31
# <DEBUG-Entity> - [ParentComment] Init | Length: 38
# <DEBUG-Entity> - [ParentComment] Init | Length: 103
# <DEBUG-Entity> - [ParentComment] Init | Length: 10
# <DEBUG-Entity> - [ParentComment] Init | Length: 95
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 55
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 50
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Found 50 parent comments.
# <DEBUG-Entity> - [ParentComment] Init | Length: 81
# <DEBUG-Entity> - [ParentComment] Init | Length: 110
# <DEBUG-Entity> - [ParentComment] Init | Length: 22
# <DEBUG-Entity> - [ParentComment] Init | Length: 32
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 15
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 207
# <DEBUG-Entity> - [ParentComment] Init | Length: 28
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 64
# <DEBUG-Entity> - [ParentComment] Init | Length: 49
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 71
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 12
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 139
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 89
# <DEBUG-Entity> - [ParentComment] Init | Length: 13
# <DEBUG-Entity> - [ParentComment] Init | Length: 20
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 18
# <DEBUG-Entity> - [ParentComment] Init | Length: 46
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 45
# <DEBUG-Entity> - [ParentComment] Init | Length: 37
# <DEBUG-Entity> - [ParentComment] Init | Length: 35
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 65
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 47
# <DEBUG-Entity> - [ParentComment] Init | Length: 41
# <DEBUG-Entity> - [ParentComment] Init | Length: 36
# <DEBUG-Entity> - [ParentComment] Init | Length: 17
# <DEBUG-Entity> - [ParentComment] Init | Length: 25
# <DEBUG-Entity> - [ParentComment] Init | Length: 27
# <DEBUG-Entity> - [ParentComment] Init | Length: 24
# <DEBUG-Entity> - [ParentComment] Init | Length: 30
# <DEBUG-Entity> - [ParentComment] Init | Length: 11
# <DEBUG-Entity> - [ParentComment] Init | Length: 85
# <DEBUG-Entity> - [ParentComment] Init | Length: 9
# <DEBUG-Entity> - [ParentComment] Init | Length: 52
# <DEBUG-Main> - 135

# %%
df = PrepareData.prepare_corpus_content_df(posts_entity, 100)
# Out:
# <DEBUG-PrepareData> - [prepare_corpus_content_df] Xử lý 135 bài viết | Max Comment: 5
# <DEBUG-PrepareData> - [Post 1] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 67
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Quảng Ninh: Cô gái 16 tuổi suy gan sau khi giảm cân không đúng cách...' (length: 67)
# <DEBUG-Entity> - [get_parent_comments] 50 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 50
# <DEBUG-PrepareData> -   - Comment #1 | length: 196 | preview: 'Cô được chẩn đoán rối loạn chức năng gan nghiêm trọng, men g...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 99 | preview: 'Tập Gym là chân ái, vừa khỏe vừa an toàn 😄 em bảo đi tập thì...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 39 | preview: ':))))) mong mẹ tôi kh nhìn thấy bài này...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 82 | preview: 'sao giừ còn uống thuốc giảm cân được zị 🥲🥲 ăn heathy thâm hụ...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 66 | preview: '4.5 tháng giảm dc 18 kg nè...biết cách ăn uống ít lại là giả...'
# <DEBUG-PrepareData> -   - Comment #6 | length: 33 | preview: 'ăn ít lại tập thể dục vào là được...'
# <DEBUG-PrepareData> -   - Comment #7 | length: 36 | preview: 'Chắc lại mỗi sáng uống cốt chanh rồi...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 36 | preview: 'Ơn bame ban cho thân hình mình dây 🥲...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 46 | preview: 'Đi tập đi mấy mẹ🤓t cũng gần chết vì ngoo đây:)...'
# <DEBUG-PrepareData> -   - Comment #10 | length: 233 | preview: 'Giảm cân lành mạnh cần sự kiên trì nhưng an toàn và bền vững...'
# <DEBUG-PrepareData> -   - Comment #11 | length: 54 | preview: 'Xin lỗi vì đã không yêu thương bản thân mình sớm hơn 🥹...'
# <DEBUG-PrepareData> -   - Comment #12 | length: 53 | preview: 'Diễm Diễm thôi khỏi giảm đi mắc công bịnh chếc sớm 🤣🤣...'
# <DEBUG-PrepareData> -   - Comment #13 | length: 47 | preview: 'Còn t phải đi tập và ăn thật nhiều để tăng kg 😂...'
# <DEBUG-PrepareData> -   - Comment #14 | length: 86 | preview: 'Ăn đúng,, uống đủ, vận động hợp lý, bổ sung nguồn dinh dưỡng...'
# <DEBUG-PrepareData> -   - Comment #15 | length: 109 | preview: 'Ăn uống điều độ tập luyện đều đặn thôi .  Bao giờ có điều ki...'
# <DEBUG-PrepareData> -   - Comment #16 | length: 9 | preview: 'Ố zề luôn...'
# <DEBUG-PrepareData> -   - Comment #17 | length: 10 | preview: 'thôi bỏ mẹ...'
# <DEBUG-PrepareData> -   - Comment #18 | length: 477 | preview: 'Giảm cân cũng phải đủ chất nhé mn ơi ngta khuyến cáo là hạn ...'
# <DEBUG-PrepareData> -   - Comment #19 | length: 157 | preview: 'Oi troi. Cuộc đời này sướng nhất là ăn ngon ngủ kĩ nên hơi b...'
# <DEBUG-PrepareData> -   - Comment #20 | length: 68 | preview: 'Bởi thế t cứ ăn cho béo ,xong gan nhiễm mỡ,máu nhiễm mỡ t cũ...'
# <DEBUG-PrepareData> -   - Comment #21 | length:
'
# <DEBUG-PrepareData> -   - Comment #5 | length: 7 | preview: 'no care...'
# <DEBUG-PrepareData> -   - Comment #6 | length: 35 | preview: 'Cụ có cái khán đài tên loạn xị ngậu...'
# <DEBUG-PrepareData> -   - Comment #7 | length: 22 | preview: 'Có mưa không anh em 😅😅...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 41 | preview: 'Ngày hôm nay ta cùng hợp hoan nơi đây !!!...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 22 | preview: 'sẵn sàng r gai mẹ ơi 😇...'
# <DEBUG-PrepareData> -   - Comment #10 | length: 24 | preview: 'Em sẵn sàng rồi Gai ơiii...'
# <DEBUG-PrepareData> -   - Comment #11 | length: 33 | preview: 'Lee Lợi view chỗ a cũng  k tệ nha...'
# <DEBUG-PrepareData> -   - Comment #12 | length: 46 | preview: 'Sợ quá.. các con thiêu thân hay bị ánh sáng dụ...'
# <DEBUG-PrepareData> -   - Comment #13 | length: 55 | preview: 'May quá tưởng mấy thằng saygexx may mà các anh trai men...'
# <DEBUG-PrepareData> -   - Comment #14 | length: 157 | preview: 'Mn ơi vào acc tik tok em xem live săn váy cưới thanh lí giá ...'
# <DEBUG-PrepareData> -   - Comment #15 | length: 17 | preview: 'Là thằng quái nào...'
# <DEBUG-PrepareData> -   - Comment #17 | length: 84 | preview: 'Mom nào chưa book được makeup thì tới concert liên hệ tớ nha...'
# <DEBUG-PrepareData> -   - Comment #18 | length: 3 | preview: '......'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 17
# <DEBUG-PrepareData> - [Post 11] Thêm 17 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 12] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 433
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Ông Vương Nhật Thường sống tại một khu tập thể là kỹ sư kết cấu về hưu. Năm 2020...' (length: 433)
# <DEBUG-Entity> - [get_parent_comments] 9 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 9
# <DEBUG-PrepareData> -   - Comment #1 | length: 199 | preview: 'Tháng 10/2020, sáng chế của ông được Cục Sở hữu trí tuệ quốc...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 24 | preview: 'Ở Việt Nam! Lại phạt cho...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 44 | preview: 'Kỹ sư xây dựng mất tiền lương vì ông này :))...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 53 | preview: 'Ban quản lý tòa nhà cũng cấp phép cho cá nhân này à ?...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 24 | preview: 'Looks dangerous as hell....'
# <DEBUG-PrepareData> -   - Comment #6 | length: 4 | preview: 'Kinh...'
# <DEBUG-PrepareData> -   - Comment #7 | length: 35 | preview: 'mới đọc tưởng bác Phạm Nhật Vượng 🙂...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 69 | preview: 'Cmt dưới nói phạt vì tự ý làm không cho phép rất tiếc là cấp...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 48 | preview: 'Chinhs quyền có cho phép không mà ông tự làm thế...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 9
# <DEBUG-PrepareData> - [Post 12] Thêm 9 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 13] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 1244
# <DEBUG-PrepareData> - [Bước 1] Post content: 'TẤT TẦN TẬT NHỮNG ƯU ĐÃI MÀ VINGROUP DÀNH CHO CÁC "GAI CON"  1. Xanh SM: Tặng mã...' (length: 1244)
# <DEBUG-Entity> - [get_parent_comments] 8 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 8
# <DEBUG-PrepareData> -   - Comment #1 | length: 63 | preview: 'Đẳng cấp gaicon là đây chứ đâu, về "nhà" được Gai mẹ quá o b...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 27 | preview: 'Sĩ nhất đời rồi Hồng Trương...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 28 | preview: 'Nguyễn Đăng Bình đi tiếp khh...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 8 | preview: 'Thien Ly...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 15 | preview: 'Nguyễn Thu Thúy...'
# <DEBUG-PrepareData> -   - Comment #6 | length: 18 | preview: 'Nguyen Thien Thanh...'
# <DEBUG-PrepareData> -   - Comment #7 | length: 7 | preview: 'Tẩy não...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 14 | preview: 'Trần Cẩm Tú hê...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 8
# <DEBUG-PrepareData> - [Post 13] Thêm 8 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 14] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 413
# <DEBUG-PrepareData> - [Bước 1] Post content: 'MỘT ĐÁM CƯỚI GIẢN DỊ CỦA ĐÔI BẠN TRẺ NGƯỜI Ê-ĐÊ   Yêu 5 năm thì có 2 năm chàng t...' (length: 413)
# <DEBUG-Entity> - [get_parent_comments] 0 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 0
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 0
# <DEBUG-PrepareData> - [Post 14] Thêm 0 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 15] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 171
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Điểm mặt lại nhan sắc của Top 25 người đẹp  tại buổi họp báo chung kết Hoa hậu V...' (length: 171)
# <DEBUG-Entity> - [get_parent_comments] 1 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 1
# <DEBUG-PrepareData> -   - Comment #1 | length: 756 | preview: 'DANH SÁCH TOP 25 NGƯỜI ĐẸP:
#
# Hoàng Thị Tú Anh - SBD: 135
# P...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 1
# <DEBUG-PrepareData> - [Post 15] Thêm 1 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 16] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 82
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Campuchia cắt băng thông Internet từ Thái Lan, yêu cầu quân đội 'cảnh giác cao đ...' (length: 82)
# <DEBUG-Entity> - [get_parent_comments] 1 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 1
# <DEBUG-PrepareData> -   - Comment #1 | length: 1953 | preview: 'Thủ tướng Campuchia thông báo cắt băng thông Internet từ Thá...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 1
# <DEBUG-PrepareData> - [Post 16] Thêm 1 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 17] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 183
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Hoa Hậu Huỳnh Thị Thanh Thuỷ với nhan sắc cuốn hút xuất hiện tại họp báo chung k...' (length: 183)
# <DEBUG-Entity> - [get_parent_comments] 5 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 5
# <DEBUG-PrepareData> -   - Comment #1 | length: 23 | preview: '23 tuổi làm GK HHVN (y)...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 8 | preview: 'Xinh quá...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 86 | preview: 'Thanh Thủy quá xinh đẹp, lại thông minh, tài giỏi nữa,quá xứ...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 30 | preview: 'Thủy đẹp,giỏi nữa.Tuyệt vời ❤️...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 39 | preview: 'Hh này vẫn còn hợp tác sen vàng phải ko...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 5
# <DEBUG-PrepareData> - [Post 17] Thêm 5 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 18] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 458
# <DEBUG-PrepareData> - [Bước 1] Post content: 'CẢNH TƯỢNG CHƯA TỪNG THẤY TẠI ĐẬP THỦY LỢI Ở ĐÀ NẴNG, DÂN NUÔI CÁ MẤT TRẮNG TIỀN...' (length: 458)
# <DEBUG-Entity> - [get_parent_comments] 50 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 50
# <DEBUG-PrepareData> -   - Comment #1 | length: 42 | preview: 'Ước tính số cá bị cuốn trôi khoảng 50 tấn....'
# <DEBUG-PrepareData> -   - Comment #2 | length: 50 | preview: '500 a e báo cho Trấn Thành để kêu gọi ngay lập tức...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 34 | preview: 'Vớt vát đc ít để có tiền đóng thuế...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 94 | preview: 'Dân còn khổ, cơ sở vật chất còn nghèo nàn, mà Nhà nước cứ tư...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 100 | preview: 'Cảnh này t đã từng. Từ đó t phải từ bỏ đam mê. 1 là vì hết s...'
# <DEBUG-PrepareData> -   - Comment #6 | length: 78 | preview: 'Mưa tầm tã mấy ngày thế đỡ làm giao đc🥲
# Vào giao hàng có 2 n...'
# <DEBUG-PrepareData> -   - Comment #7 | length: 167 | preview: 'Dân thì è cổ ra làm,ko may là mất trắng thế mà các bác rảnh ...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 48 | preview: 'Này đúng kẻ cười người khóc ni..ae bắt cá 🐟🐟 vui...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 3 | preview: 'Khổ...'
# <DEBUG-PrepareData> -   - Comment #10 | length: 179 | preview: '50 tấn x 44k = 2 tỷ 2 chưa tính lồng đấy là tính cả lãi, còn...'
# <DEBUG-PrepareData> -   - Comment #11 | length: 31 | preview: 'Đung là chỉ biết khóc . khổ quá...'
# ...
# <DEBUG-PrepareData> -   - Comment #8 | length: 103 | preview: 'Ui. Người nhà mình cũng chạy xe dịch vụ. Mỗi khi gặp khách k...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 196 | preview: 'Nhiều người đi group 5 mà book xe 4c. Lên xe chỉ nói câu: “c...'
# <DEBUG-PrepareData> -   - Comment #10 | length: 117 | preview: 'Trong trường hợp này thì hợp lý nhất là xuống 1 người. Mà cụ...'
# <DEBUG-PrepareData> -   - Comment #11 | length: 88 | preview: 'Có lần đặt be xe máy mà bảo chở 4 người 2 vk 2 đứa con nghĩ ...'
# <DEBUG-PrepareData> -   - Comment #12 | length: 23 | preview: 'Thứ Này Ở Quê Tao Đầy 😁...'
# <DEBUG-PrepareData> -   - Comment #13 | length: 85 | preview: 'Có lần tài xế đồng ý nhận 5 cô cháu nhà mình, mình lên xe ph...'
# <DEBUG-PrepareData> -   - Comment #14 | length: 114 | preview: 'Muốn con m thoải mái đat 7 chỗ ma đi ￼ con có tiền nữa mua x...'
# <DEBUG-PrepareData> -   - Comment #15 | length: 288 | preview: 'trong clip này ai đúng ai sai tui ko dám phán, nhưng tui boo...'
# <DEBUG-PrepareData> -   - Comment #16 | length: 35 | preview: 'Dựng ghế lái thì bác tài xuống xe à...'
# <DEBUG-PrepareData> -   - Comment #17 | length: 102 | preview: 'Nhà t 2 ng vs con 1t toàn đặt xe 7 chỗ đi cho rộng rãi thoải...'
# <DEBUG-PrepareData> -   - Comment #18 | length: 42 | preview: 'Kiện giùm luôn đi 🤣🤣🤣 thiếu kiếm thức mà …...'
# <DEBUG-PrepareData> -   - Comment #19 | length: 51 | preview: 'Bạn có thể yêu cầu chính bất kỳ ghế nào trừ ghế lái...'
# <DEBUG-PrepareData> -   - Comment #20 | length: 73 | preview: 'Sao không có luật 3 trẻ em là 2 người lớn. Học theo các nước...'
# <DEBUG-PrepareData> -   - Comment #21 | length: 209 | preview: 'Nói thiệt chứ người Việt minh khi đặt phòng ks hay xe thì lu...'
# <DEBUG-PrepareData> -   - Comment #22 | length: 294 | preview: 'Bắt tài xế thay đổi vị trí ghế lái là biết ngô như thế nào r...'
# <DEBUG-PrepareData> -   - Comment #23 | length: 258 | preview: 'Bác tài này còn hiền gặp bác tài khác cho ra bãi đất trống x...'
# <DEBUG-PrepareData> -   - Comment #24 | length: 34 | preview: 'khách hàng chứ éo phải ông nội :))...'
# <DEBUG-PrepareData> -   - Comment #25 | length: 50 | preview: 'Đề nghị các hãng xe từ chối phục vụ gia đình này 😁...'
# <DEBUG-PrepareData> -   - Comment #26 | length: 56 | preview: 'Luat mới ra trẻ con cung phai tính mot ghế ko đọc luật à...'
# <DEBUG-PrepareData> -   - Comment #27 | length: 81 | preview: 'Đòi tài xế dựng cả ghế lái thì gia đình mình chắc muốn đi xe...'
# <DEBUG-PrepareData> -   - Comment #28 | length: 23 | preview: 'Bó tay cái bọn khôn lõi...'
# <DEBUG-PrepareData> -   - Comment #29 | length: 199 | preview: 'Rồi công an phạt thì gđ có chịu đóng phạt ko. Xe đăng ký 5 c...'
# <DEBUG-PrepareData> -   - Comment #30 | length: 100 | preview: 'Tranh cãi làm gì với con người đó.
# Luật nó ghi rõ ràng rồi m...'
# <DEBUG-PrepareData> -   - Comment #31 | length: 69 | preview: 'Toàn làm clips vô duyên không có khách nào ngu đến vậy đâu x...'
# <DEBUG-PrepareData> -   - Comment #32 | length: 35 | preview: '5ng đi xe 7chỗ chứ ai bảo cố chở lz...'
# <DEBUG-PrepareData> -   - Comment #33 | length: 84 | preview: 'Tài xế làm vậy là sai rồi . Lẽ ra nên xuống đi bộ nhường ghế...'
# <DEBUG-PrepareData> -   - Comment #34 | length: 78 | preview: 'Book xe khác thôi.. có zây cũg đào lớn chuyện.. thúi rùm chứ...'
# <DEBUG-PrepareData> -   - Comment #35 | length: 56 | preview: 'Đặt moẹ nó 7 chỗ đi ngồi có phải sướng cái thằng ng ko 🙄...'
# <DEBUG-PrepareData> -   - Comment #36 | length: 51 | preview: 'Phong cách của ng gia trưởng, và luôn đẻ ra con gái...'
# <DEBUG-PrepareData> -   - Comment #37 | length: 79 | preview: 'Hãng cấm chở gia súc gia cầm trên xe mà. Ông tài xế làm vậy ...'
# <DEBUG-PrepareData> -   - Comment #38 | length: 28 | preview: 'Du người nếu bị phạt ai chịu...'
# <DEBUG-PrepareData> -   - Comment #39 | length: 40 | preview: 'việc đặt xe 4 chô và 5 chỗ n khó vậy sao...'
# <DEBUG-PrepareData> -   - Comment #40 | length: 195 | preview: 'Lbu thằng khách trọ trẹ , cứ nhảy vào mồm ng ta, rồi nó nghĩ...'
# <DEBUG-PrepareData> -   - Comment #41 | length: 80 | preview: 'Mịa nhà m cũng có con nhỏ mà sao n ng hãm thế. Ê m đang chửi...'
# <DEBUG-PrepareData> -   - Comment #42 | length: 63 | preview: 'Khách hãm đã quá số người còn muốn rộng vậy sao k book 7 chỗ...'
# <DEBUG-PrepareData> -   - Comment #43 | length: 114 | preview: 'Đòi dựng ghế lái lên thì cũng đến chịu luôn ạ, rồi lái xe ng...'
# <DEBUG-PrepareData> -   - Comment #44 | length: 111 | preview: 'Đã 5 người còn đặt 4 chỗ
# Đã thế còn yêu cầu tài xế dựng ghế...'
# <DEBUG-PrepareData> -   - Comment #45 | length: 39 | preview: 'Tới lúc bị phạt thì khách có thấy đâu 🥹...'
# <DEBUG-PrepareData> -   - Comment #46 | length: 32 | preview: 'Cái này mình ủng hộ bác tài 100%...'
# <DEBUG-PrepareData> -   - Comment #47 | length: 51 | preview: 'Trên xe. Riêng ghế tài xế là không ai được động vào...'
# <DEBUG-PrepareData> -   - Comment #48 | length: 13 | preview: 'Đặt 4 mà đi 5...'
# <DEBUG-PrepareData> -   - Comment #49 | length: 28 | preview: 'đưa xe cho ỗng bã lái luôn 😅...'
# <DEBUG-PrepareData> -   - Comment #50 | length: 62 | preview: 'Lái xe họ phải có tư thế phù hợp để lái. Ủng hộ bác tài nhé ...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 50
# <DEBUG-PrepareData> - [Post 71] Thêm 50 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 72] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Gần 1.200 cán bộ, công chức ở Hải Dương xin nghỉ việc...' (length: 53)
# <DEBUG-Entity> - [get_parent_comments] 1 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 1
# <DEBUG-PrepareData> -   - Comment #1 | length: 834 | preview: 'Gần 1.200 cán bộ, công chức, viên chức ở Hải Dương xin nghỉ ...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 1
# <DEBUG-PrepareData> - [Post 72] Thêm 1 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 73] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 39
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Đứng hình mất 5 giây...   Video: comcom...' (length: 39)
# <DEBUG-Entity> - [get_parent_comments] 0 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 0
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 0
# <DEBUG-PrepareData> - [Post 73] Thêm 0 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 74] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 118
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Bão số 1 sẽ đạt cấp mạnh nhất trong 24 giờ tới và liên tục đổi hướng di chuyển, ...' (length: 118)
# <DEBUG-Entity> - [get_parent_comments] 19 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 19
# <DEBUG-PrepareData> -   - Comment #1 | length: 731 | preview: 'Trung tâm Dự báo Khí tượng Thủy văn quốc gia cho biết lúc 7h...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 81 | preview: 'Hy vọng bão sẽ đánh bay cái nết mấy mẹ hàng xóm gần nhà, bay...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 42 | preview: 'Mong là mẹ thiên nhiên dịu dàng vs năm nay...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 103 | preview: 'Ai đi vũng tàu, hòn Sơn, phú quốc thì đợi qua bão hả đi chứ ...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 41 | preview: 'Gia lai mưa cả tuần rồi còn chưa ngớt nữa...'
# <DEBUG-PrepareData> -   - Comment #6 | length: 26 | preview: 'Mưa lớn khỏi tưới cây khỏe...'
# <DEBUG-PrepareData> -   - Comment #7 | length: 25 | preview: 'Sơn tây vẩn nắng vàng mắt...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 17 | preview: 'Miền Bắc thì saoo...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 104 | preview: 'Bão vậy mà mấy ông đi biển.coi chuẩn bị ứng phó bão  chứ im ...'
# <DEBUG-PrepareData> -   - Comment #10 | length: 7 | preview: 'Quá khổ...'
# <DEBUG-PrepareData> -   - Comment #11 | length: 8 | preview: 'Mạnh lên...'
# <DEBUG-PrepareData> -   - Comment #12 | length: 3 | preview: 'Rồi...'
# <DEBUG-PrepareData> -   - Comment #13 | length: 39 | preview: 'chưa kịp đi du lịch mà đã bão vs bùng 😭...'
# <DEBUG-PrepareData> -   - Comment #14 | length: 4 | preview: 'Amen...'
# <DEBUG-PrepareData> -   - Comment #15 | length: 5 | preview: 'Khổ 🥲...'
# <DEBUG-PrepareData> -   - Comment #16 | length: 26 | preview: 'Pleiku mưa tầm tã ngày đêm...'
# <DEBUG-PrepareData> -   - Comment #17 | length: 42 | preview: 'Mưa xuốt từ lúc về chưa ngừng nghỉ sợ thật...'
# <DEBUG-PrepareData> -   - Comment #18 | length: 31 | preview: 'Gia Lai mưa xuất thì chịu rồi 😌...'
# <DEBUG-PrepareData> -   - Comment #19 | length: 35 | preview: 'Lại mưa hả mới ngưng dc 30p thôi mà...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 19
# <DEBUG-PrepareData> - [Post 74] Thêm 19 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 75] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 143
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Sau sáp nhập tỉnh thành: Người dân có thể dùng giấy tờ cũ đến khi hết hạn, nếu c...' (length: 143)
# <DEBUG-Entity> - [get_parent_comments] 4 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 4
# <DEBUG-PrepareData> -   - Comment #1 | length: 1321 | preview: 'Người dân và doanh nghiệp tiếp tục sử dụng giấy tờ đã được c...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 23 | preview: '13 năm nữa mới hết hạn😂...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 39 | preview: 'Phí không so so co đi tới lui nhiều lần...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 69 | preview: 'Sau khi sát nhập thì về kinh tế sài gòn vượt trội hơn hẳn Hà...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 4
# <DEBUG-PrepareData> - [Post 75] Thêm 4 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 76] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 30
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Giờ là biển vô cực Hưng Yên......' (length: 30)
# <DEBUG-Entity> - [get_parent_comments] 2 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 2
# <DEBUG-PrepareData> -   - Comment #1 | length: 28 | preview: 'Hơi nhiều bùn đất tí thôi kk...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 25 | preview: 'sếp Tùng quê ở Hưng yên à...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 2
# <DEBUG-PrepareData> - [Post 76] Thêm 2 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 77] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 1260
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Cơ hội vào thẳng top 15 sẽ dành cho "Người đẹp được khán giả bình chọn nhiều nhấ...' (length: 1260)
# <DEBUG-Entity> - [get_parent_comments] 1 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 1
# <DEBUG-PrepareData> -   - Comment #1 | length: 374 | preview: 'Cách thức bình chọn:
# Bước 1: Truy cập https://hhvn.lasoong.c...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 1
# <DEBUG-PrepareData> - [Post 77] Thêm 1 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 78] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Anh em Cá Mập - Đại Bàng chúng mình cứ thế thôi hẹ hẹ...' (length: 53)
# <DEBUG-Entity> - [get_parent_comments] 3 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 3
# <DEBUG-PrepareData> -   - Comment #1 | length: 1 | preview: '👍...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 28 | preview: 'Hai bạn này đẹp trai thế nhỉ...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 2
# <DEBUG-PrepareData> - [Post 78] Thêm 2 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 79] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 127
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Tổng Bí thư Tô Lâm, Chủ tịch nước Lương Cường gửi điện mừng đến Tổng thống Nga V...' (length: 127)
# <DEBUG-Entity> - [get_parent_comments] 1 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 1
# <DEBUG-PrepareData> -   - Comment #1 | length: 870 | preview: 'Tổng Bí thư Tô Lâm, Chủ tịch nước Lương Cường gửi điện mừng ...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 1
# <DEBUG-PrepareData> - [Post 79] Thêm 1 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 80] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 85
# <DEBUG-PrepareData> - [Bước 1] Post content: '🇻🇳 Bản đồ 34 tỉnh, thành phố trên cả nước từ ngày 12/6/2025  🇻🇳    THEO: BÁO NHÂ...' (length: 85)
# <DEBUG-Entity> - [get_parent_comments] 1 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 1
# <DEBUG-PrepareData> -   - Comment #1 | length: 392 | preview: 'CHI TIẾT SỐ LƯỢNG CÁN BỘ, CÔNG CHỨC, VIÊN CHỨC; TRỤ SỞ CẤP T...'
# <DEBUG-PrepareData> - [Bước 3] Tổng số mẫu ghép: 1
# <DEBUG-PrepareData> - [Post 80] Thêm 1 dòng vào DataFrame
# <DEBUG-PrepareData> - [Post 81] Đang xử lý post
# <DEBUG-Entity> - [get_post_text] Length: 119
# <DEBUG-PrepareData> - [Bước 1] Post content: 'Thương lắm Quảng Nam ơi, do ảnh hưởng của bão số 1, Quảng Nam mưa lớn gây ngập l...' (length: 119)
# <DEBUG-Entity> - [get_parent_comments] 50 bình luận cha
# <DEBUG-PrepareData> - [Bước 2] Số lượng comment cha: 50
# <DEBUG-PrepareData> -   - Comment #1 | length: 53 | preview: 'Thương người dân quảng nam mình lắm luôn á mn ơi...'
# <DEBUG-PrepareData> -   - Comment #2 | length: 92 | preview: 'Vừa thủy điện xã lủ 800/s vừa mưa to, gia súc gia cầm đều ☠️...'
# <DEBUG-PrepareData> -   - Comment #3 | length: 44 | preview: 'giàu nhiêu lũ quét sạch riết mệt, thương quê...'
# <DEBUG-PrepareData> -   - Comment #4 | length: 10 | preview: 'Thương quá...'
# <DEBUG-PrepareData> -   - Comment #5 | length: 19 | preview: 'Nhìn thương thật sự...'
# <DEBUG-PrepareData> -   - Comment #6 | length: 17 | preview: 'Khổ cho dân mình....'
# <DEBUG-PrepareData> -   - Comment #7 | length: 19 | preview: 'Thương nhân dân quá...'
# <DEBUG-PrepareData> -   - Comment #8 | length: 19 | preview: 'Ở mình thì mình mưa...'
# <DEBUG-PrepareData> -   - Comment #9 | length: 10 | preview: 'Thương lắm...'
# <DEBUG-PrepareData> -   - Comment #10 | length: 82 | preview: 'Chỗ mình thì trời tối tối, mưa bay bay, đc 2,3 hôm nay rồi, ...'
# <DEBUG-PrepareData> -   - Comment #11 | length: 10 | preview: 'Thưông qua...'
# <DEBUG-PrepareData> -   - Comment #12 | length: 36 | preview: 'Sao không mua lu về hứng cho đỡ ngập...'
# <DEBUG-PrepareData> -   - Comment #13 | length: 7 | preview: 'Xin giá...'
# <DEBUG-PrepareData> -   - Comment #14 | length: 10 | preview: 'Khổ rứa tr...'
# <DEBUG-PrepareData> -   - Comment #15 | length: 10 | preview: 'Thương quá...'
# <DEBUG-PrepareData> -   - Comment #16 | length: 75 | preview: 'Mình mới tính sương sương đã đăng xuất hơn chục trịu trôi th...'
# <DEBUG-PrepareData> -   - Comment #17 | length: 13 | preview: 'Thương quá 😭😢...'
# <DEBUG-PrepareData> -   - Comment #18 | length: 29 | preview: 'Adidaphat adidaphat adidaphat...'
# <DEBUG-PrepareData> -   - Comment #19 | length: 12 | preview: 'Thương thật!...'
# <DEBUG-PrepareData> -   - Comment #20 | length: 114 | preview: 'Không liên quan. Nhưng hỏi ad chút. Là mấy bài viết này lại ...'
# <DEBUG-PrepareData> -   - Comment #21 | length: 37 | preview: 'Ngọc Bích  chỗ nhà chị có vc gì không...'
# <DEBUG-PrepareData> -   - Comment #22 | length: 71 | preview: 'Bác nào Hội An cập nhật cho e xin hình ảnh với.e đang trên đ...'
# <DEBUG-PrepareData> -   - Comment #23 | length: 18 | preview: 'ở núi thành hả sốp...'
# <DEBUG-PrepareData> -   - Comment #24 | length: 10 | preview: 'Thương quá...'
# <DEBUG-PrepareData> -   - Comment #25 | length: 85 | preview: 'Tội quá có người bị cuốn rồi ạ
# Mình ở gần đó quay được, vide...'
# <DEBUG-PrepareData> -   - Comment #26 | length: 3 | preview: 'Khổ...'
# <DEBUG-PrepareData> -   - Comment #27 | length: 12 | preview: 'Thương quá ạ...'
# <DEBUG-PrepareData> -   - Comment #28 | length: 12 | preview: 'Khổ thân quá...'
# <DEBUG-PrepareData> -   - Comment #29 | length: 43 | preview: 'Quảng Nam quê tôi mà huyện nào vậy mn người...'
# <DEBUG-PrepareData> -   - Comment #30 | length: 22 | preview: 'Năm nay mùa lũ lại đến...'
# <DEBUG-PrepareData> -   - Comment #31 | length: 44 | preview: 'Thương quá cứ đến mùa mưa bão là dân lại khổ...'
# <DEBUG-PrepareData> -   - Comment #32 | length: 19 | preview: 'Quảng Nam ơi cố lên...'
# <DEBUG-PrepareData> -   - Comment #33 | length: 19 | preview: 'Thương dân mình quá...'
# <DEBUG-PrepareData> -   - Comment #34 | length: 24 | preview: 'Thương quá miền Trung ơi...'

# %%
data_file = "content_posts.csv"
Utils.write_csv(df, data_file)
