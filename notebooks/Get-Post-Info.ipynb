# %%
# !git clone https://github.com/hoivd/SocialTrend
# Out:
# Cloning into 'SocialTrend'...
# remote: Enumerating objects: 1487, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 1487 (delta 5), reused 16 (delta 3), pack-reused 1469 (from 2)
# Receiving objects: 100% (1487/1487), 232.51 MiB | 40.51 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# # IMPORT THƯ VIỆN

# %%
import logging
import json
from typing import List, Dict, Optional
import re
from collections import Counter
import pandas as pd
from SocialTrend.scripts.clone_data import HFDatasetCloner
from SocialTrend.scripts.logger import _setup_logger
from datetime import datetime
import os

# %%
logger_level = logging.DEBUG

# %% [markdown]
# # UTILS

# %%
utils_logger = _setup_logger("Utils", logger_level)

class Utils:
    @staticmethod
    def load_json(file_path: str) -> dict:
        """Đọc file .json và trả về dữ liệu dưới dạng dict hoặc list."""
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                utils_logger.debug(f"Load FILE JSON {file_path} thành công")
                return data
        except Exception as e:
            utils_logger.debug(f"Load FILE JSON {file_path} thất bại")
            raise Exception(e)

    @staticmethod
    def load_jsonl(file_path: str) -> List[Dict]:
        """Đọc file .jsonl và trả về list chứa các dict (mỗi dòng là một JSON).
    
        Args:
            file_path (str): Đường dẫn tới file .jsonl
            utils_logger: Logger đã được cấu hình sẵn (thường dùng logging.getLogger(...))
    
        Returns:
            List[Dict]: Danh sách các dòng JSON đã parse thành dict
        """
        data = []
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                for line_num, line in enumerate(f, start=1):
                    line = line.strip()
                    if line:
                        try:
                            data.append(json.loads(line))
                        except json.JSONDecodeError as e:
                            utils_logger.debug(f"Lỗi JSON ở dòng {line_num}: {e}")
        except FileNotFoundError:
            utils_logger.debug(f"Không tìm thấy file: {file_path}")
        except Exception as e:
            utils_logger.debug(f"Lỗi khi đọc file '{file_path}': {e}")
        return data

    @staticmethod
    def write_csv(data: List[Dict], file_path: str, encoding: str = "utf-8", index: bool = False) -> None:
        """
        Ghi list[dict] hoặc pandas.DataFrame ra file CSV.
    
        Args:
            data (List[Dict] or pd.DataFrame): Dữ liệu cần ghi.
            file_path (str): Đường dẫn file CSV đầu ra.
            encoding (str): Kiểu mã hóa (mặc định: "utf-8").
            index (bool): Có ghi chỉ số dòng (index) hay không (mặc định: False).
        """
        try:
            if isinstance(data, pd.DataFrame):
                df = data
            else:
                df = pd.DataFrame(data)
    
            df.to_csv(file_path, index=index, encoding=encoding)
            utils_logger.debug(f"[write_csv] ✅ Đã ghi {len(df)} dòng vào '{file_path}'")
    
        except Exception as e:
            utils_logger.debug(f"[write_csv] ❌ Lỗi khi ghi CSV: {e}")

# %% [markdown]
# # POST ENTITY

# %%
entity_logger = _setup_logger("Entity", logger_level)

# %%
class CommentReactionsInfo:
    def __init__(self, reaction_data: Dict):
        self.total = reaction_data.get("total", 0)
        self.detail = reaction_data.get("detail", {}) or {}
        self.reaction_key_map = {
            k.lower(): k for k in self.detail.keys()
        }

    def get_total(self) -> int:
        return self.total

    def get_count(self, reaction: str) -> int:
        key = self.reaction_key_map.get(reaction.lower())
        if key is None:
            entity_logger.debug(f"[CommentReactionsInfo] '{reaction}' không tồn tại trong reaction_key_map")
            return 0
        return self.detail.get(key, 0)

    def get_percentage(self, reaction: str) -> float:
        count = self.get_count(reaction)
        return (count / self.total) * 100 if self.total > 0 else 0.0

    def get_all_counts(self) -> Dict[str, int]:
        return dict(self.detail)

    def get_all_percentages(self) -> Dict[str, float]:
        return {
            k: round((v / self.total) * 100, 2) if self.total > 0 else 0.0
            for k, v in self.detail.items()
        }

    def most_common(self, top_n: int = 2) -> List[tuple]:
        return sorted(self.detail.items(), key=lambda x: x[1], reverse=True)[:top_n]

    def get_available_reactions(self) -> List[str]:
        return list(self.detail.keys())

# %%
class ParentComment:
    def __init__(self, data: Dict):
        self.text = data.get("text", "")
        self.reactions_raw = data.get("reactions", {})
        self.raw = data

        entity_logger.debug(f"[ParentComment] Init | Length: {self.length()}")

    def get_text(self) -> str:
        return self.text

    def has_link(self) -> bool:
        has = "http" in self.text
        entity_logger.debug(f"[ParentComment] has_link: {has}")
        return has

    def length(self) -> int:
        return len(self.text)

    def get_keywords(self) -> List[str]:
        words = re.findall(r'\w+', self.text.lower())
        entity_logger.debug(f"[ParentComment] {len(words)} keywords")
        return words

    def get_reactions_info(self) -> CommentReactionsInfo:
        entity_logger.debug("[ParentComment] get_reactions_info")
        return CommentReactionsInfo(self.reactions_raw)

    def get_reaction_count(self) -> int:
        info = self.get_reactions_info()
        return info.get_total()

    def to_dict(self) -> Dict:
        return {
            "text": self.text,
            "reaction_count": self.get_reaction_count(),
            "has_link": self.has_link(),
            "length": self.length(),
        }

# %%
class ReactionsInfo:
    def __init__(self, reaction_dict: Dict[str, int]):
        self.reactions = reaction_dict or {}
        self.total = sum(self.reactions.values())       

    def get_total(self) -> int:
        return self.total

    def get_count(self, reaction: str) -> int:
        """Trả về số lượng reaction theo tên không phân biệt hoa thường"""
        key = reaction
        if key is None:
            entity_logger.debug(f"[get_count] '{reaction}' không tồn tại trong reaction_key_map")
            return 0
        return self.reactions.get(key, 0)

    def get_percentage(self, reaction: str) -> float:
        count = self.get_count(reaction)
        return (count / self.total) * 100 if self.total > 0 else 0.0

    def get_all_counts(self) -> Dict[str, int]:
        return dict(self.reactions)

    def get_all_percentages(self) -> Dict[str, float]:
        return {
            k: round((v / self.total) * 100, 2) if self.total > 0 else 0.0
            for k, v in self.reactions.items()
        }

    def most_common(self, top_n: int = 3) -> List[tuple]:
        return sorted(self.reactions.items(), key=lambda x: x[1], reverse=True)[:top_n]

    def get_available_reactions(self) -> List[str]:
        """Trả về danh sách các loại cảm xúc có mặt trong post"""
        return list(self.reactions.keys())

# %%
class FacebookPost:
    def __init__(self, data: Dict):
        entity_logger.debug("[FacebookPost] Initializing...")
        self.data = data

    def get_creation_time(self) -> Optional[str]:
        ts = self.data.get("creation_time")
        if ts:
            try:
                dt = datetime.utcfromtimestamp(ts)
                formatted = dt.strftime('%Y-%m-%d %H:%M:%S UTC')
                entity_logger.debug(f"[get_creation_time] Formatted time: {formatted}")
                return formatted
            except Exception as e:
                entity_logger.debug(f"[get_creation_time] Error formatting timestamp: {e}")
        return None

    def get_reactions_info(self) -> ReactionsInfo:
        reaction_data = self.data.get("reactions_detail", {})
        entity_logger.debug(f"[get_reactions_info] Raw: {reaction_data}")
        return ReactionsInfo(reaction_data)

    def get_post_text(self) -> str:
        text = self.data.get("post_content", "")
        entity_logger.debug(f"[get_post_text] Length: {len(text)}")
        return text

    def get_post_url(self) -> str:
        return self.data.get("post_url", "")

    def get_total_reactions(self) -> int:
        total = self.data.get("total_reactions", 0)
        entity_logger.debug(f"[get_total_reactions] Total: {total}")
        return total

    def get_reaction_breakdown(self) -> Dict[str, int]:
        reactions = self.data.get("reactions_detail", {})
        entity_logger.debug(f"[get_reaction_breakdown] Reactions: {reactions}")
        return reactions

    def get_comment_count(self) -> int:
        count = self.data.get("comment_count", 0)
        entity_logger.debug(f"[get_comment_count] Total: {count}")
        return count

    def get_share_count(self) -> int:
        try:
            share_count = int(self.data.get("share_count", "0"))
        except ValueError:
            share_count = 0
        entity_logger.debug(f"[get_share_count] Share count: {share_count}")
        return share_count

    def get_parent_comments(self) -> List[ParentComment]:
        raw_comments = data.get("comments", {}).get("comments", [])
        entity_logger.debug(f"[FacebookPost] Found {len(raw_comments)} parent comments.")
        self.parent_comments: List[ParentComment] = [
            ParentComment(c) for c in raw_comments
        ]
        entity_logger.debug(f"[get_parent_comments] {len(self.parent_comments)} bình luận cha")
        return self.parent_comments

    def get_average_comment_length(self) -> float:
        if not self.parent_comments:
            return 0.0
        lengths = [c.length() for c in self.parent_comments]
        avg = sum(lengths) / len(lengths)
        entity_logger.debug(f"[get_average_comment_length] Trung bình: {avg}")
        return avg

    def get_link_comments(self) -> List[ParentComment]:
        linked = [c for c in self.parent_comments if c.has_link()]
        entity_logger.debug(f"[get_link_comments] Có {len(linked)} bình luận chứa link")
        return linked

    def get_top_keywords_in_comments(self, top_n: int = 10) -> List[tuple]:
        counter = Counter()
        for c in self.parent_comments:
            counter.update(c.get_keywords())
        result = counter.most_common(top_n)
        entity_logger.debug(f"[get_top_keywords_in_comments] Top {top_n}: {result}")
        return result

    def get_first_comment_with_link(self) -> Optional[ParentComment]:
        for c in self.parent_comments:
            if c.has_link():
                entity_logger.debug("[get_first_comment_with_link] Tìm thấy bình luận có link")
                return c
        entity_logger.debug("[get_first_comment_with_link] Không có bình luận nào chứa link")
        return None

    def print_basic_info(self):
        print("📄 THÔNG TIN BÀI VIẾT")
        print("-" * 40)
        print(f"🕒 Thời gian đăng   : {self.get_creation_time()}")
        print(f"🔗 URL             : {self.get_post_url()}")
        print(f"💬 Nội dung        : {self.get_post_text()[:100]}{'...' if len(self.get_post_text()) > 100 else ''}")
        print()
        print(f"👍 Tổng reaction   : {self.get_total_reactions()}")
        print(f"💬 Tổng comment    : {self.get_comment_count()}")
        print(f"🔁 Tổng share      : {self.get_share_count()}")
        print()
        print(f"👨‍👩‍👧‍👦 Số bình luận cha : {len(self.get_parent_comments())}")
        print(f"✏️ Độ dài TB bình luận: {self.get_average_comment_length():.2f} ký tự")
        print(f"🔗 Bình luận có link  : {len(self.get_link_comments())}")
        print("-" * 40)

# %% [markdown]
# # PREPARE DATA

# %%
prepare_logger = _setup_logger("PrepareData", logger_level)

# %%
class PostDataLoader:
    @staticmethod
    def get_posts_file(root_dir: str) -> List[str]:
        """
        Trả về danh sách tất cả file .json trong thư mục (bao gồm thư mục con)
        """
        json_files = []
        prepare_logger.info(f"📂 Tìm post data trong: {root_dir}")

        for root, dirs, files in os.walk(root_dir):
            for file in files:
                if file.lower().endswith('.json'):
                    full_path = os.path.join(root, file)
                    prepare_logger.debug(f"   └── 📄 Tìm thấy: {file}")
                    json_files.append(full_path)

        return json_files

    @staticmethod
    def get_posts_data(post_files: List[str]) -> List[Dict]:
        """
        Đọc dữ liệu từ danh sách file JSON và gộp lại thành một list
        """
        all_posts = []

        for file_path in post_files:
            try:
                data = Utils.load_json(file_path)
                if isinstance(data, list):
                    all_posts.extend(data)
                else:
                    all_posts.append(data)
                prepare_logger.debug(f"✅ Load xong {file_path} ({len(data)} item)")
            except Exception as e:
                prepare_logger.debug(f"❌ Lỗi khi load {file_path}: {e}")
        
        prepare_logger.info(f"📦 Tổng số post load được: {len(all_posts)}")
        return all_posts

    def __call__(self, root_dir: str) -> List[Dict]:
        """
        Cho phép gọi class như một hàm để lấy toàn bộ post từ thư mục
        """
        prepare_logger.info(f"🚀 Bắt đầu load post data từ: {root_dir}")
        post_files = self.get_posts_file(root_dir)
        posts_data = self.get_posts_data(post_files)
        return posts_data

# %%
class PrepareData:
    @staticmethod
    def prepare_post_comment_data(post: FacebookPost, max_comment: int = 50) -> List[str]:
        """
        Thực hiện các bước:
        Bước 1: Lấy nội dung bài post (post content)
        Bước 2: Lấy danh sách parent comment và nội dung từng comment
        Bước 3: Với mỗi comment, ghép nội dung post + comment thành một chuỗi → trả về list
        """
        # Bước 1: lấy nội dung post
        post_text = post.get_post_text().strip()
        prepare_logger.debug(f"[Bước 1] Post content: '{post_text[:80]}...' (length: {len(post_text)})")

        # Bước 2: lấy comment cha
        parent_comments = post.get_parent_comments()
        prepare_logger.debug(f"[Bước 2] Số lượng comment cha: {len(parent_comments)}")

        comment_texts = []
        n_comment = len(parent_comments)
        top_k_cmt = min(n_comment, max_comment)
        for i, c in enumerate(parent_comments[:top_k_cmt]):
            text = c.get_text().strip()
            if text:
                comment_texts.append(text)
                prepare_logger.debug(f"  - Comment #{i+1} | length: {len(text)} | preview: '{text[:60]}...'")

        # Bước 3: ghép post + comment
        merged_texts = [f"{post_text}\n\n{comment}" for comment in comment_texts]
        prepare_logger.debug(f"[Bước 3] Tổng số mẫu ghép: {len(merged_texts)}")

        return merged_texts

    @staticmethod
    def prepare_corpus_post_comment_df(posts: List[FacebookPost], max_comment: int = 50) -> pd.DataFrame:
        """
        Trả về DataFrame gồm 2 cột: 'content' và 'post_id'
        - 'content': văn bản sau khi merge post content + comment content
        - 'post_id': lấy từ 'feedback_id' trong dict gốc
        """
        prepare_logger.debug(f"[prepare_corpus_post_comment_df] Xử lý {len(posts)} bài viết | Max Comment: {max_comment}")
    
        records = []
    
        for i, post in enumerate(posts):
            try:
                prepare_logger.debug(f"[Post {i+1}] Đang xử lý post")
                post_id = i + 1
                merged_texts = PrepareData.prepare_post_comment_data(post, max_comment)
    
                for content in merged_texts:
                    records.append({
                        "post_id": post_id,
                        "content": content
                    })
    
                prepare_logger.debug(f"[Post {i+1}] Thêm {len(merged_texts)} dòng vào DataFrame")
    
            except Exception as e:
                prepare_logger.debug(f"[Post {i+1}] Lỗi: {e}")
    
        df = pd.DataFrame(records)
        prepare_logger.debug(f"[prepare_corpus_post_comment_df] Tổng số dòng: {len(df)}")
        return df

    @staticmethod
    def prepare_corpus_post_df(posts: List[FacebookPost]) -> pd.DataFrame:
        """
        Tạo DataFrame chỉ gồm nội dung post (không có comment).
        
        Returns:
            pd.DataFrame với 2 cột:
                - 'post_id': ID thứ tự
                - 'content': nội dung bài viết
        """
        prepare_logger.debug(f"[prepare_corpus_post_only_df] Tổng số bài viết: {len(posts)}")
        
        records = []
        
        for i, post in enumerate(posts):
            try:
                content = post.get_post_text().strip()
                if content:
                    records.append({
                        "post_id": i + 1,
                        "content": content
                    })
                    prepare_logger.debug(f"[Post {i+1}] ✔ Thêm post content, length: {len(content)}")
                else:
                    prepare_logger.debug(f"[Post {i+1}] ⚠ Post content rỗng")
            except Exception as e:
                prepare_logger.debug(f"[Post {i+1}] ❌ Lỗi: {e}")
        
        df = pd.DataFrame(records)
        prepare_logger.debug(f"[prepare_corpus_post_only_df] ✅ Tổng số dòng: {len(df)}")
        return df

# %% [markdown]
# # MAIN

# %% [markdown]
# ## Load Posts

# %%
datasets_dir = "./kaggle/datasets"
posts_dir = datasets_dir + "/data/json"

# %%
cloner = HFDatasetCloner("hoivd/SocialData")
cloner.clone_folder("data/json", local_dir="./kaggle/datasets")
# Out:
# 📂 Cloning folder: data/json
#   ⬇️  Downloading: data/json/posts_K14vn.json
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:980: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# posts_K14vn.json:   0%|          | 0.00/3.44M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_K14vn_2025-6-14.jsonl
# posts_K14vn_2025-6-14.jsonl:   0%|          | 0.00/2.28M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_Theanh28.json
# posts_Theanh28.json:   0%|          | 0.00/6.65M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_Theanh28.jsonl
#   ⬇️  Downloading: data/json/posts_Theanh28_2025-6-14.jsonl
# posts_Theanh28_2025-6-14.jsonl:   0%|          | 0.00/4.29M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_beatvn.network.json
# posts_beatvn.network.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_beatvn.network_2025-6-14.jsonl
# posts_beatvn.network_2025-6-14.jsonl:   0%|          | 0.00/10.3M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_congdongvnexpress.json
# posts_congdongvnexpress.json:   0%|          | 0.00/1.12M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_congdongvnexpress_2025-6-14.jsonl
# posts_congdongvnexpress_2025-6-14.jsonl:   0%|          | 0.00/760k [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_yannews.json
# posts_yannews.json:   0%|          | 0.00/3.83M [00:00<?, ?B/s]
#   ⬇️  Downloading: data/json/posts_yannews_2025-6-14.jsonl
# posts_yannews_2025-6-14.jsonl:   0%|          | 0.00/2.44M [00:00<?, ?B/s]
# ✅ Đã tải 11 file từ thư mục data/json
# ['kaggle/datasets/data/json/posts_K14vn.json',
#  'kaggle/datasets/data/json/posts_K14vn_2025-6-14.jsonl',
#  'kaggle/datasets/data/json/posts_Theanh28.json',
#  'kaggle/datasets/data/json/posts_Theanh28.jsonl',
#  'kaggle/datasets/data/json/posts_Theanh28_2025-6-14.jsonl',
#  'kaggle/datasets/data/json/posts_beatvn.network.json',
#  'kaggle/datasets/data/json/posts_beatvn.network_2025-6-14.jsonl',
#  'kaggle/datasets/data/json/posts_congdongvnexpress.json',
#  'kaggle/datasets/data/json/posts_congdongvnexpress_2025-6-14.jsonl',
#  'kaggle/datasets/data/json/posts_yannews.json',
#  'kaggle/datasets/data/json/posts_yannews_2025-6-14.jsonl']

# %%
logger = _setup_logger("Main", logger_level)

# %%
post_loader = PostDataLoader()
posts_data = post_loader(posts_dir)
# Out:
# <INFO-PrepareData> - 🚀 Bắt đầu load post data từ: ./kaggle/datasets/data/json
# <INFO-PrepareData> - 📂 Tìm post data trong: ./kaggle/datasets/data/json
# <DEBUG-PrepareData> -    └── 📄 Tìm thấy: posts_beatvn.network.json
# <DEBUG-PrepareData> -    └── 📄 Tìm thấy: posts_yannews.json
# <DEBUG-PrepareData> -    └── 📄 Tìm thấy: posts_Theanh28.json
# <DEBUG-PrepareData> -    └── 📄 Tìm thấy: posts_K14vn.json
# <DEBUG-PrepareData> -    └── 📄 Tìm thấy: posts_congdongvnexpress.json
# <DEBUG-Utils> - Load FILE JSON ./kaggle/datasets/data/json/posts_beatvn.network.json thành công
# <DEBUG-PrepareData> - ✅ Load xong ./kaggle/datasets/data/json/posts_beatvn.network.json (177 item)
# <DEBUG-Utils> - Load FILE JSON ./kaggle/datasets/data/json/posts_yannews.json thành công
# <DEBUG-PrepareData> - ✅ Load xong ./kaggle/datasets/data/json/posts_yannews.json (163 item)
# <DEBUG-Utils> - Load FILE JSON ./kaggle/datasets/data/json/posts_Theanh28.json thành công
# <DEBUG-PrepareData> - ✅ Load xong ./kaggle/datasets/data/json/posts_Theanh28.json (135 item)
# <DEBUG-Utils> - Load FILE JSON ./kaggle/datasets/data/json/posts_K14vn.json thành công
# <DEBUG-PrepareData> - ✅ Load xong ./kaggle/datasets/data/json/posts_K14vn.json (185 item)
# <DEBUG-Utils> - Load FILE JSON ./kaggle/datasets/data/json/posts_congdongvnexpress.json thành công
# <DEBUG-PrepareData> - ✅ Load xong ./kaggle/datasets/data/json/posts_congdongvnexpress.json (195 item)
# <INFO-PrepareData> - 📦 Tổng số post load được: 855

# %%
posts = [FacebookPost(p) for p in posts_data]
# Out:
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...
# <DEBUG-Entity> - [FacebookPost] Initializing...

# %%
df = PrepareData.prepare_corpus_post_df(posts)
# Out:
# <DEBUG-PrepareData> - [prepare_corpus_post_only_df] Tổng số bài viết: 855
# <DEBUG-Entity> - [get_post_text] Length: 847
# <DEBUG-PrepareData> - [Post 1] ✔ Thêm post content, length: 847
# <DEBUG-Entity> - [get_post_text] Length: 650
# <DEBUG-PrepareData> - [Post 2] ✔ Thêm post content, length: 650
# <DEBUG-Entity> - [get_post_text] Length: 3007
# <DEBUG-PrepareData> - [Post 3] ✔ Thêm post content, length: 3007
# <DEBUG-Entity> - [get_post_text] Length: 777
# <DEBUG-PrepareData> - [Post 4] ✔ Thêm post content, length: 777
# <DEBUG-Entity> - [get_post_text] Length: 126
# <DEBUG-PrepareData> - [Post 5] ✔ Thêm post content, length: 126
# <DEBUG-Entity> - [get_post_text] Length: 1309
# <DEBUG-PrepareData> - [Post 6] ✔ Thêm post content, length: 1309
# <DEBUG-Entity> - [get_post_text] Length: 918
# <DEBUG-PrepareData> - [Post 7] ✔ Thêm post content, length: 918
# <DEBUG-Entity> - [get_post_text] Length: 153
# <DEBUG-PrepareData> - [Post 8] ✔ Thêm post content, length: 153
# <DEBUG-Entity> - [get_post_text] Length: 811
# <DEBUG-PrepareData> - [Post 9] ✔ Thêm post content, length: 811
# <DEBUG-Entity> - [get_post_text] Length: 204
# <DEBUG-PrepareData> - [Post 10] ✔ Thêm post content, length: 204
# <DEBUG-Entity> - [get_post_text] Length: 256
# <DEBUG-PrepareData> - [Post 11] ✔ Thêm post content, length: 256
# <DEBUG-Entity> - [get_post_text] Length: 1477
# <DEBUG-PrepareData> - [Post 12] ✔ Thêm post content, length: 1477
# <DEBUG-Entity> - [get_post_text] Length: 564
# <DEBUG-PrepareData> - [Post 13] ✔ Thêm post content, length: 564
# <DEBUG-Entity> - [get_post_text] Length: 703
# <DEBUG-PrepareData> - [Post 14] ✔ Thêm post content, length: 703
# <DEBUG-Entity> - [get_post_text] Length: 553
# <DEBUG-PrepareData> - [Post 15] ✔ Thêm post content, length: 553
# <DEBUG-Entity> - [get_post_text] Length: 653
# <DEBUG-PrepareData> - [Post 16] ✔ Thêm post content, length: 653
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 17] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 168
# <DEBUG-PrepareData> - [Post 18] ✔ Thêm post content, length: 168
# <DEBUG-Entity> - [get_post_text] Length: 1733
# <DEBUG-PrepareData> - [Post 19] ✔ Thêm post content, length: 1733
# <DEBUG-Entity> - [get_post_text] Length: 551
# <DEBUG-PrepareData> - [Post 20] ✔ Thêm post content, length: 551
# <DEBUG-Entity> - [get_post_text] Length: 729
# <DEBUG-PrepareData> - [Post 21] ✔ Thêm post content, length: 729
# <DEBUG-Entity> - [get_post_text] Length: 557
# <DEBUG-PrepareData> - [Post 22] ✔ Thêm post content, length: 557
# <DEBUG-Entity> - [get_post_text] Length: 60
# <DEBUG-PrepareData> - [Post 23] ✔ Thêm post content, length: 60
# <DEBUG-Entity> - [get_post_text] Length: 967
# <DEBUG-PrepareData> - [Post 24] ✔ Thêm post content, length: 967
# <DEBUG-Entity> - [get_post_text] Length: 94
# <DEBUG-PrepareData> - [Post 25] ✔ Thêm post content, length: 94
# <DEBUG-Entity> - [get_post_text] Length: 147
# <DEBUG-PrepareData> - [Post 26] ✔ Thêm post content, length: 147
# <DEBUG-Entity> - [get_post_text] Length: 135
# <DEBUG-PrepareData> - [Post 27] ✔ Thêm post content, length: 135
# <DEBUG-Entity> - [get_post_text] Length: 1120
# <DEBUG-PrepareData> - [Post 28] ✔ Thêm post content, length: 1120
# <DEBUG-Entity> - [get_post_text] Length: 761
# <DEBUG-PrepareData> - [Post 29] ✔ Thêm post content, length: 761
# <DEBUG-Entity> - [get_post_text] Length: 930
# <DEBUG-PrepareData> - [Post 30] ✔ Thêm post content, length: 930
# <DEBUG-Entity> - [get_post_text] Length: 851
# <DEBUG-PrepareData> - [Post 31] ✔ Thêm post content, length: 851
# <DEBUG-Entity> - [get_post_text] Length: 57
# <DEBUG-PrepareData> - [Post 32] ✔ Thêm post content, length: 57
# <DEBUG-Entity> - [get_post_text] Length: 583
# <DEBUG-PrepareData> - [Post 33] ✔ Thêm post content, length: 583
# <DEBUG-Entity> - [get_post_text] Length: 712
# <DEBUG-PrepareData> - [Post 34] ✔ Thêm post content, length: 712
# <DEBUG-Entity> - [get_post_text] Length: 544
# <DEBUG-PrepareData> - [Post 35] ✔ Thêm post content, length: 544
# <DEBUG-Entity> - [get_post_text] Length: 986
# <DEBUG-PrepareData> - [Post 36] ✔ Thêm post content, length: 986
# <DEBUG-Entity> - [get_post_text] Length: 583
# <DEBUG-PrepareData> - [Post 37] ✔ Thêm post content, length: 583
# <DEBUG-Entity> - [get_post_text] Length: 1696
# <DEBUG-PrepareData> - [Post 38] ✔ Thêm post content, length: 1696
# <DEBUG-Entity> - [get_post_text] Length: 176
# <DEBUG-PrepareData> - [Post 39] ✔ Thêm post content, length: 176
# <DEBUG-Entity> - [get_post_text] Length: 913
# <DEBUG-PrepareData> - [Post 40] ✔ Thêm post content, length: 913
# <DEBUG-Entity> - [get_post_text] Length: 28
# <DEBUG-PrepareData> - [Post 41] ✔ Thêm post content, length: 28
# <DEBUG-Entity> - [get_post_text] Length: 102
# <DEBUG-PrepareData> - [Post 42] ✔ Thêm post content, length: 102
# <DEBUG-Entity> - [get_post_text] Length: 56
# <DEBUG-PrepareData> - [Post 43] ✔ Thêm post content, length: 56
# <DEBUG-Entity> - [get_post_text] Length: 11
# <DEBUG-PrepareData> - [Post 44] ✔ Thêm post content, length: 11
# <DEBUG-Entity> - [get_post_text] Length: 105
# <DEBUG-PrepareData> - [Post 45] ✔ Thêm post content, length: 105
# <DEBUG-Entity> - [get_post_text] Length: 21
# <DEBUG-PrepareData> - [Post 46] ✔ Thêm post content, length: 21
# <DEBUG-Entity> - [get_post_text] Length: 826
# <DEBUG-PrepareData> - [Post 47] ✔ Thêm post content, length: 826
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 48] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 788
# <DEBUG-PrepareData> - [Post 49] ✔ Thêm post content, length: 788
# <DEBUG-Entity> - [get_post_text] Length: 608
# <DEBUG-PrepareData> - [Post 50] ✔ Thêm post content, length: 608
# <DEBUG-Entity> - [get_post_text] Length: 992
# <DEBUG-PrepareData> - [Post 51] ✔ Thêm post content, length: 992
# <DEBUG-Entity> - [get_post_text] Length: 680
# <DEBUG-PrepareData> - [Post 52] ✔ Thêm post content, length: 680
# <DEBUG-Entity> - [get_post_text] Length: 159
# <DEBUG-PrepareData> - [Post 53] ✔ Thêm post content, length: 159
# <DEBUG-Entity> - [get_post_text] Length: 61
# <DEBUG-PrepareData> - [Post 54] ✔ Thêm post content, length: 61
# <DEBUG-Entity> - [get_post_text] Length: 502
# <DEBUG-PrepareData> - [Post 55] ✔ Thêm post content, length: 502
# <DEBUG-Entity> - [get_post_text] Length: 1585
# <DEBUG-PrepareData> - [Post 56] ✔ Thêm post content, length: 1585
# <DEBUG-Entity> - [get_post_text] Length: 666
# <DEBUG-PrepareData> - [Post 57] ✔ Thêm post content, length: 666
# <DEBUG-Entity> - [get_post_text] Length: 58
# <DEBUG-PrepareData> - [Post 58] ✔ Thêm post content, length: 58
# <DEBUG-Entity> - [get_post_text] Length: 26
# <DEBUG-PrepareData> - [Post 59] ✔ Thêm post content, length: 26
# <DEBUG-Entity> - [get_post_text] Length: 226
# <DEBUG-PrepareData> - [Post 60] ✔ Thêm post content, length: 226
# <DEBUG-Entity> - [get_post_text] Length: 110
# <DEBUG-PrepareData> - [Post 61] ✔ Thêm post content, length: 110
# <DEBUG-Entity> - [get_post_text] Length: 529
# <DEBUG-PrepareData> - [Post 62] ✔ Thêm post content, length: 529
# <DEBUG-Entity> - [get_post_text] Length: 546
# <DEBUG-PrepareData> - [Post 63] ✔ Thêm post content, length: 546
# <DEBUG-Entity> - [get_post_text] Length: 412
# <DEBUG-PrepareData> - [Post 64] ✔ Thêm post content, length: 412
# <DEBUG-Entity> - [get_post_text] Length: 1100
# <DEBUG-PrepareData> - [Post 65] ✔ Thêm post content, length: 1100
# <DEBUG-Entity> - [get_post_text] Length: 1000
# <DEBUG-PrepareData> - [Post 66] ✔ Thêm post content, length: 1000
# <DEBUG-Entity> - [get_post_text] Length: 1118
# <DEBUG-PrepareData> - [Post 67] ✔ Thêm post content, length: 1118
# <DEBUG-Entity> - [get_post_text] Length: 189
# <DEBUG-PrepareData> - [Post 68] ✔ Thêm post content, length: 189
# <DEBUG-Entity> - [get_post_text] Length: 1058
# <DEBUG-PrepareData> - [Post 69] ✔ Thêm post content, length: 1058
# <DEBUG-Entity> - [get_post_text] Length: 17
# <DEBUG-PrepareData> - [Post 70] ✔ Thêm post content, length: 17
# <DEBUG-Entity> - [get_post_text] Length: 774
# <DEBUG-PrepareData> - [Post 71] ✔ Thêm post content, length: 774
# <DEBUG-Entity> - [get_post_text] Length: 435
# <DEBUG-PrepareData> - [Post 72] ✔ Thêm post content, length: 435
# <DEBUG-Entity> - [get_post_text] Length: 991
# <DEBUG-PrepareData> - [Post 73] ✔ Thêm post content, length: 991
# <DEBUG-Entity> - [get_post_text] Length: 408
# <DEBUG-PrepareData> - [Post 74] ✔ Thêm post content, length: 408
# <DEBUG-Entity> - [get_post_text] Length: 153
# <DEBUG-PrepareData> - [Post 75] ✔ Thêm post content, length: 153
# <DEBUG-Entity> - [get_post_text] Length: 168
# <DEBUG-PrepareData> - [Post 76] ✔ Thêm post content, length: 168
# <DEBUG-Entity> - [get_post_text] Length: 85
# <DEBUG-PrepareData> - [Post 77] ✔ Thêm post content, length: 85
# <DEBUG-Entity> - [get_post_text] Length: 118
# <DEBUG-PrepareData> - [Post 78] ✔ Thêm post content, length: 118
# <DEBUG-Entity> - [get_post_text] Length: 88
# <DEBUG-PrepareData> - [Post 79] ✔ Thêm post content, length: 88
# <DEBUG-Entity> - [get_post_text] Length: 60
# <DEBUG-PrepareData> - [Post 80] ✔ Thêm post content, length: 60
# <DEBUG-Entity> - [get_post_text] Length: 57
# <DEBUG-PrepareData> - [Post 81] ✔ Thêm post content, length: 57
# <DEBUG-Entity> - [get_post_text] Length: 2608
# <DEBUG-PrepareData> - [Post 82] ✔ Thêm post content, length: 2608
# <DEBUG-Entity> - [get_post_text] Length: 296
# <DEBUG-PrepareData> - [Post 83] ✔ Thêm post content, length: 296
# <DEBUG-Entity> - [get_post_text] Length: 145
# <DEBUG-PrepareData> - [Post 84] ✔ Thêm post content, length: 145
# <DEBUG-Entity> - [get_post_text] Length: 564
# <DEBUG-PrepareData> - [Post 85] ✔ Thêm post content, length: 564
# <DEBUG-Entity> - [get_post_text] Length: 826
# <DEBUG-PrepareData> - [Post 86] ✔ Thêm post content, length: 826
# <DEBUG-Entity> - [get_post_text] Length: 780
# <DEBUG-PrepareData> - [Post 87] ✔ Thêm post content, length: 780
# <DEBUG-Entity> - [get_post_text] Length: 155
# <DEBUG-PrepareData> - [Post 88] ✔ Thêm post content, length: 155
# <DEBUG-Entity> - [get_post_text] Length: 145
# <DEBUG-PrepareData> - [Post 89] ✔ Thêm post content, length: 145
# <DEBUG-Entity> - [get_post_text] Length: 722
# <DEBUG-PrepareData> - [Post 90] ✔ Thêm post content, length: 722
# <DEBUG-Entity> - [get_post_text] Length: 156
# <DEBUG-PrepareData> - [Post 91] ✔ Thêm post content, length: 156
# <DEBUG-Entity> - [get_post_text] Length: 866
# <DEBUG-PrepareData> - [Post 92] ✔ Thêm post content, length: 866
# <DEBUG-Entity> - [get_post_text] Length: 697
# <DEBUG-PrepareData> - [Post 93] ✔ Thêm post content, length: 697
# <DEBUG-Entity> - [get_post_text] Length: 495
# <DEBUG-PrepareData> - [Post 94] ✔ Thêm post content, length: 495
# <DEBUG-Entity> - [get_post_text] Length: 102
# <DEBUG-PrepareData> - [Post 95] ✔ Thêm post content, length: 102
# <DEBUG-Entity> - [get_post_text] Length: 503
# <DEBUG-PrepareData> - [Post 96] ✔ Thêm post content, length: 503
# <DEBUG-Entity> - [get_post_text] Length: 811
# <DEBUG-PrepareData> - [Post 97] ✔ Thêm post content, length: 811
# <DEBUG-Entity> - [get_post_text] Length: 1044
# <DEBUG-PrepareData> - [Post 98] ✔ Thêm post content, length: 1044
# <DEBUG-Entity> - [get_post_text] Length: 154
# <DEBUG-PrepareData> - [Post 99] ✔ Thêm post content, length: 154
# <DEBUG-Entity> - [get_post_text] Length: 148
# <DEBUG-PrepareData> - [Post 100] ✔ Thêm post content, length: 148
# <DEBUG-Entity> - [get_post_text] Length: 397
# <DEBUG-PrepareData> - [Post 101] ✔ Thêm post content, length: 397
# <DEBUG-Entity> - [get_post_text] Length: 554
# <DEBUG-PrepareData> - [Post 102] ✔ Thêm post content, length: 554
# <DEBUG-Entity> - [get_post_text] Length: 1677
# <DEBUG-PrepareData> - [Post 103] ✔ Thêm post content, length: 1677
# <DEBUG-Entity> - [get_post_text] Length: 1058
# <DEBUG-PrepareData> - [Post 104] ✔ Thêm post content, length: 1058
# <DEBUG-Entity> - [get_post_text] Length: 1063
# <DEBUG-PrepareData> - [Post 105] ✔ Thêm post content, length: 1063
# <DEBUG-Entity> - [get_post_text] Length: 94
# <DEBUG-PrepareData> - [Post 106] ✔ Thêm post content, length: 94
# <DEBUG-Entity> - [get_post_text] Length: 97
# <DEBUG-PrepareData> - [Post 107] ✔ Thêm post content, length: 97
# <DEBUG-Entity> - [get_post_text] Length: 601
# <DEBUG-PrepareData> - [Post 108] ✔ Thêm post content, length: 601
# <DEBUG-Entity> - [get_post_text] Length: 709
# <DEBUG-PrepareData> - [Post 109] ✔ Thêm post content, length: 709
# <DEBUG-Entity> - [get_post_text] Length: 588
# <DEBUG-PrepareData> - [Post 110] ✔ Thêm post content, length: 588
# <DEBUG-Entity> - [get_post_text] Length: 743
# <DEBUG-PrepareData> - [Post 111] ✔ Thêm post content, length: 743
# <DEBUG-Entity> - [get_post_text] Length: 1018
# <DEBUG-PrepareData> - [Post 112] ✔ Thêm post content, length: 1018
# <DEBUG-Entity> - [get_post_text] Length: 1247
# <DEBUG-PrepareData> - [Post 113] ✔ Thêm post content, length: 1247
# <DEBUG-Entity> - [get_post_text] Length: 142
# <DEBUG-PrepareData> - [Post 114] ✔ Thêm post content, length: 142
# <DEBUG-Entity> - [get_post_text] Length: 384
# <DEBUG-PrepareData> - [Post 115] ✔ Thêm post content, length: 384
# <DEBUG-Entity> - [get_post_text] Length: 762
# <DEBUG-PrepareData> - [Post 116] ✔ Thêm post content, length: 762
# <DEBUG-Entity> - [get_post_text] Length: 571
# <DEBUG-PrepareData> - [Post 117] ✔ Thêm post content, length: 571
# <DEBUG-Entity> - [get_post_text] Length: 225
# <DEBUG-PrepareData> - [Post 118] ✔ Thêm post content, length: 225
# <DEBUG-Entity> - [get_post_text] Length: 824
# <DEBUG-PrepareData> - [Post 119] ✔ Thêm post content, length: 824
# <DEBUG-Entity> - [get_post_text] Length: 334
# <DEBUG-PrepareData> - [Post 120] ✔ Thêm post content, length: 334
# <DEBUG-Entity> - [get_post_text] Length: 133
# <DEBUG-PrepareData> - [Post 121] ✔ Thêm post content, length: 133
# <DEBUG-Entity> - [get_post_text] Length: 1386
# <DEBUG-PrepareData> - [Post 122] ✔ Thêm post content, length: 1386
# <DEBUG-Entity> - [get_post_text] Length: 654
# <DEBUG-PrepareData> - [Post 123] ✔ Thêm post content, length: 654
# <DEBUG-Entity> - [get_post_text] Length: 212
# <DEBUG-PrepareData> - [Post 124] ✔ Thêm post content, length: 212
# <DEBUG-Entity> - [get_post_text] Length: 830
# <DEBUG-PrepareData> - [Post 125] ✔ Thêm post content, length: 830
# <DEBUG-Entity> - [get_post_text] Length: 83
# <DEBUG-PrepareData> - [Post 126] ✔ Thêm post content, length: 83
# <DEBUG-Entity> - [get_post_text] Length: 818
# <DEBUG-PrepareData> - [Post 127] ✔ Thêm post content, length: 818
# <DEBUG-Entity> - [get_post_text] Length: 112
# <DEBUG-PrepareData> - [Post 128] ✔ Thêm post content, length: 112
# <DEBUG-Entity> - [get_post_text] Length: 429
# <DEBUG-PrepareData> - [Post 129] ✔ Thêm post content, length: 429
# <DEBUG-Entity> - [get_post_text] Length: 733
# <DEBUG-PrepareData> - [Post 130] ✔ Thêm post content, length: 733
# <DEBUG-Entity> - [get_post_text] Length: 896
# <DEBUG-PrepareData> - [Post 131] ✔ Thêm post content, length: 896
# <DEBUG-Entity> - [get_post_text] Length: 603
# <DEBUG-PrepareData> - [Post 132] ✔ Thêm post content, length: 603
# <DEBUG-Entity> - [get_post_text] Length: 3047
# <DEBUG-PrepareData> - [Post 133] ✔ Thêm post content, length: 3047
# <DEBUG-Entity> - [get_post_text] Length: 477
# <DEBUG-PrepareData> - [Post 134] ✔ Thêm post content, length: 477
# <DEBUG-Entity> - [get_post_text] Length: 590
# <DEBUG-PrepareData> - [Post 135] ✔ Thêm post content, length: 590
# <DEBUG-Entity> - [get_post_text] Length: 1787
# <DEBUG-PrepareData> - [Post 136] ✔ Thêm post content, length: 1787
# <DEBUG-Entity> - [get_post_text] Length: 221
# <DEBUG-PrepareData> - [Post 137] ✔ Thêm post content, length: 221
# <DEBUG-Entity> - [get_post_text] Length: 65
# <DEBUG-PrepareData> - [Post 138] ✔ Thêm post content, length: 65
# <DEBUG-Entity> - [get_post_text] Length: 978
# <DEBUG-PrepareData> - [Post 139] ✔ Thêm post content, length: 978
# <DEBUG-Entity> - [get_post_text] Length: 439
# <DEBUG-PrepareData> - [Post 140] ✔ Thêm post content, length: 439
# <DEBUG-Entity> - [get_post_text] Length: 477
# <DEBUG-PrepareData> - [Post 141] ✔ Thêm post content, length: 477
# <DEBUG-Entity> - [get_post_text] Length: 317
# <DEBUG-PrepareData> - [Post 142] ✔ Thêm post content, length: 317
# <DEBUG-Entity> - [get_post_text] Length: 1829
# <DEBUG-PrepareData> - [Post 143] ✔ Thêm post content, length: 1829
# <DEBUG-Entity> - [get_post_text] Length: 994
# <DEBUG-PrepareData> - [Post 144] ✔ Thêm post content, length: 994
# <DEBUG-Entity> - [get_post_text] Length: 1007
# <DEBUG-PrepareData> - [Post 145] ✔ Thêm post content, length: 1007
# <DEBUG-Entity> - [get_post_text] Length: 500
# <DEBUG-PrepareData> - [Post 146] ✔ Thêm post content, length: 500
# <DEBUG-Entity> - [get_post_text] Length: 526
# <DEBUG-PrepareData> - [Post 147] ✔ Thêm post content, length: 526
# <DEBUG-Entity> - [get_post_text] Length: 746
# <DEBUG-PrepareData> - [Post 148] ✔ Thêm post content, length: 746
# <DEBUG-Entity> - [get_post_text] Length: 355
# <DEBUG-PrepareData> - [Post 149] ✔ Thêm post content, length: 355
# <DEBUG-Entity> - [get_post_text] Length: 671
# <DEBUG-PrepareData> - [Post 150] ✔ Thêm post content, length: 671
# <DEBUG-Entity> - [get_post_text] Length: 82
# <DEBUG-PrepareData> - [Post 151] ✔ Thêm post content, length: 82
# <DEBUG-Entity> - [get_post_text] Length: 2175
# <DEBUG-PrepareData> - [Post 152] ✔ Thêm post content, length: 2175
# <DEBUG-Entity> - [get_post_text] Length: 28
# <DEBUG-PrepareData> - [Post 153] ✔ Thêm post content, length: 28
# <DEBUG-Entity> - [get_post_text] Length: 306
# <DEBUG-PrepareData> - [Post 154] ✔ Thêm post content, length: 306
# <DEBUG-Entity> - [get_post_text] Length: 116
# <DEBUG-PrepareData> - [Post 155] ✔ Thêm post content, length: 116
# <DEBUG-Entity> - [get_post_text] Length: 99
# <DEBUG-PrepareData> - [Post 156] ✔ Thêm post content, length: 99
# <DEBUG-Entity> - [get_post_text] Length: 140
# <DEBUG-PrepareData> - [Post 157] ✔ Thêm post content, length: 140
# <DEBUG-Entity> - [get_post_text] Length: 580
# <DEBUG-PrepareData> - [Post 158] ✔ Thêm post content, length: 580
# <DEBUG-Entity> - [get_post_text] Length: 354
# <DEBUG-PrepareData> - [Post 159] ✔ Thêm post content, length: 354
# <DEBUG-Entity> - [get_post_text] Length: 478
# <DEBUG-PrepareData> - [Post 160] ✔ Thêm post content, length: 478
# <DEBUG-Entity> - [get_post_text] Length: 961
# <DEBUG-PrepareData> - [Post 161] ✔ Thêm post content, length: 961
# <DEBUG-Entity> - [get_post_text] Length: 1026
# <DEBUG-PrepareData> - [Post 162] ✔ Thêm post content, length: 1026
# <DEBUG-Entity> - [get_post_text] Length: 493
# <DEBUG-PrepareData> - [Post 163] ✔ Thêm post content, length: 493
# <DEBUG-Entity> - [get_post_text] Length: 729
# <DEBUG-PrepareData> - [Post 164] ✔ Thêm post content, length: 729
# <DEBUG-Entity> - [get_post_text] Length: 97
# <DEBUG-PrepareData> - [Post 165] ✔ Thêm post content, length: 97
# <DEBUG-Entity> - [get_post_text] Length: 75
# <DEBUG-PrepareData> - [Post 166] ✔ Thêm post content, length: 75
# <DEBUG-Entity> - [get_post_text] Length: 226
# <DEBUG-PrepareData> - [Post 167] ✔ Thêm post content, length: 226
# <DEBUG-Entity> - [get_post_text] Length: 505
# <DEBUG-PrepareData> - [Post 168] ✔ Thêm post content, length: 505
# <DEBUG-Entity> - [get_post_text] Length: 316
# <DEBUG-PrepareData> - [Post 169] ✔ Thêm post content, length: 316
# <DEBUG-Entity> - [get_post_text] Length: 1356
# <DEBUG-PrepareData> - [Post 170] ✔ Thêm post content, length: 1356
# <DEBUG-Entity> - [get_post_text] Length: 431
# <DEBUG-PrepareData> - [Post 171] ✔ Thêm post content, length: 431
# <DEBUG-Entity> - [get_post_text] Length: 398
# <DEBUG-PrepareData> - [Post 172] ✔ Thêm post content, length: 398
# <DEBUG-Entity> - [get_post_text] Length: 273
# <DEBUG-PrepareData> - [Post 173] ✔ Thêm post content, length: 273
# <DEBUG-Entity> - [get_post_text] Length: 312
# <DEBUG-PrepareData> - [Post 174] ✔ Thêm post content, length: 312
# <DEBUG-Entity> - [get_post_text] Length: 158
# <DEBUG-PrepareData> - [Post 175] ✔ Thêm post content, length: 158
# <DEBUG-Entity> - [get_post_text] Length: 388
# <DEBUG-PrepareData> - [Post 176] ✔ Thêm post content, length: 388
# <DEBUG-Entity> - [get_post_text] Length: 39
# <DEBUG-PrepareData> - [Post 177] ✔ Thêm post content, length: 39
# <DEBUG-Entity> - [get_post_text] Length: 126
# <DEBUG-PrepareData> - [Post 178] ✔ Thêm post content, length: 126
# <DEBUG-Entity> - [get_post_text] Length: 48
# <DEBUG-PrepareData> - [Post 179] ✔ Thêm post content, length: 48
# <DEBUG-Entity> - [get_post_text] Length: 24
# <DEBUG-PrepareData> - [Post 180] ✔ Thêm post content, length: 24
# <DEBUG-Entity> - [get_post_text] Length: 106
# <DEBUG-PrepareData> - [Post 181] ✔ Thêm post content, length: 106
# <DEBUG-Entity> - [get_post_text] Length: 23
# <DEBUG-PrepareData> - [Post 182] ✔ Thêm post content, length: 23
# <DEBUG-Entity> - [get_post_text] Length: 48
# <DEBUG-PrepareData> - [Post 183] ✔ Thêm post content, length: 48
# <DEBUG-Entity> - [get_post_text] Length: 83
# <DEBUG-PrepareData> - [Post 184] ✔ Thêm post content, length: 83
# <DEBUG-Entity> - [get_post_text] Length: 36
# <DEBUG-PrepareData> - [Post 185] ✔ Thêm post content, length: 36
# <DEBUG-Entity> - [get_post_text] Length: 63
# <DEBUG-PrepareData> - [Post 186] ✔ Thêm post content, length: 63
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 187] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 84
# <DEBUG-PrepareData> - [Post 188] ✔ Thêm post content, length: 84
# <DEBUG-Entity> - [get_post_text] Length: 38
# <DEBUG-PrepareData> - [Post 189] ✔ Thêm post content, length: 38
# <DEBUG-Entity> - [get_post_text] Length: 81
# <DEBUG-PrepareData> - [Post 190] ✔ Thêm post content, length: 81
# <DEBUG-Entity> - [get_post_text] Length: 122
# <DEBUG-PrepareData> - [Post 191] ✔ Thêm post content, length: 122
# <DEBUG-Entity> - [get_post_text] Length: 45
# <DEBUG-PrepareData> - [Post 192] ✔ Thêm post content, length: 45
# <DEBUG-Entity> - [get_post_text] Length: 58
# <DEBUG-PrepareData> - [Post 193] ✔ Thêm post content, length: 58
# <DEBUG-Entity> - [get_post_text] Length: 52
# <DEBUG-PrepareData> - [Post 194] ✔ Thêm post content, length: 52
# <DEBUG-Entity> - [get_post_text] Length: 110
# <DEBUG-PrepareData> - [Post 195] ✔ Thêm post content, length: 110
# <DEBUG-Entity> - [get_post_text] Length: 85
# <DEBUG-PrepareData> - [Post 196] ✔ Thêm post content, length: 85
# <DEBUG-Entity> - [get_post_text] Length: 36
# <DEBUG-PrepareData> - [Post 197] ✔ Thêm post content, length: 36
# <DEBUG-Entity> - [get_post_text] Length: 150
# <DEBUG-PrepareData> - [Post 198] ✔ Thêm post content, length: 150
# <DEBUG-Entity> - [get_post_text] Length: 94
# <DEBUG-PrepareData> - [Post 199] ✔ Thêm post content, length: 94
# <DEBUG-Entity> - [get_post_text] Length: 60
# <DEBUG-PrepareData> - [Post 200] ✔ Thêm post content, length: 60
# <DEBUG-Entity> - [get_post_text] Length: 86
# <DEBUG-PrepareData> - [Post 201] ✔ Thêm post content, length: 86
# <DEBUG-Entity> - [get_post_text] Length: 87
# <DEBUG-PrepareData> - [Post 202] ✔ Thêm post content, length: 87
# <DEBUG-Entity> - [get_post_text] Length: 137
# <DEBUG-PrepareData> - [Post 203] ✔ Thêm post content, length: 137
# <DEBUG-Entity> - [get_post_text] Length: 114
# <DEBUG-PrepareData> - [Post 204] ✔ Thêm post content, length: 114
# <DEBUG-Entity> - [get_post_text] Length: 107
# <DEBUG-PrepareData> - [Post 205] ✔ Thêm post content, length: 107
# <DEBUG-Entity> - [get_post_text] Length: 55
# <DEBUG-PrepareData> - [Post 206] ✔ Thêm post content, length: 55
# <DEBUG-Entity> - [get_post_text] Length: 57
# <DEBUG-PrepareData> - [Post 207] ✔ Thêm post content, length: 57
# <DEBUG-Entity> - [get_post_text] Length: 94
# <DEBUG-PrepareData> - [Post 208] ✔ Thêm post content, length: 94
# <DEBUG-Entity> - [get_post_text] Length: 46
# <DEBUG-PrepareData> - [Post 209] ✔ Thêm post content, length: 46
# <DEBUG-Entity> - [get_post_text] Length: 109
# <DEBUG-PrepareData> - [Post 210] ✔ Thêm post content, length: 109
# <DEBUG-Entity> - [get_post_text] Length: 95
# <DEBUG-PrepareData> - [Post 211] ✔ Thêm post content, length: 95
# <DEBUG-Entity> - [get_post_text] Length: 80
# <DEBUG-PrepareData> - [Post 212] ✔ Thêm post content, length: 80
# <DEBUG-Entity> - [get_post_text] Length: 107
# <DEBUG-PrepareData> - [Post 213] ✔ Thêm post content, length: 107
# <DEBUG-Entity> - [get_post_text] Length: 113
# <DEBUG-PrepareData> - [Post 214] ✔ Thêm post content, length: 113
# <DEBUG-Entity> - [get_post_text] Length: 52
# <DEBUG-PrepareData> - [Post 215] ✔ Thêm post content, length: 52
# <DEBUG-Entity> - [get_post_text] Length: 99
# <DEBUG-PrepareData> - [Post 216] ✔ Thêm post content, length: 99
# <DEBUG-Entity> - [get_post_text] Length: 70
# <DEBUG-PrepareData> - [Post 217] ✔ Thêm post content, length: 70
# <DEBUG-Entity> - [get_post_text] Length: 39
# <DEBUG-PrepareData> - [Post 218] ✔ Thêm post content, length: 39
# <DEBUG-Entity> - [get_post_text] Length: 63
# <DEBUG-PrepareData> - [Post 219] ✔ Thêm post content, length: 63
# <DEBUG-Entity> - [get_post_text] Length: 92
# <DEBUG-PrepareData> - [Post 220] ✔ Thêm post content, length: 92
# <DEBUG-Entity> - [get_post_text] Length: 26
# <DEBUG-PrepareData> - [Post 221] ✔ Thêm post content, length: 26
# <DEBUG-Entity> - [get_post_text] Length: 96
# <DEBUG-PrepareData> - [Post 222] ✔ Thêm post content, length: 96
# <DEBUG-Entity> - [get_post_text] Length: 58
# <DEBUG-PrepareData> - [Post 223] ✔ Thêm post content, length: 58
# <DEBUG-Entity> - [get_post_text] Length: 85
# <DEBUG-PrepareData> - [Post 224] ✔ Thêm post content, length: 85
# <DEBUG-Entity> - [get_post_text] Length: 83
# <DEBUG-PrepareData> - [Post 225] ✔ Thêm post content, length: 83
# <DEBUG-Entity> - [get_post_text] Length: 66
# <DEBUG-PrepareData> - [Post 226] ✔ Thêm post content, length: 66
# <DEBUG-Entity> - [get_post_text] Length: 100
# <DEBUG-PrepareData> - [Post 227] ✔ Thêm post content, length: 100
# <DEBUG-Entity> - [get_post_text] Length: 79
# <DEBUG-PrepareData> - [Post 228] ✔ Thêm post content, length: 79
# <DEBUG-Entity> - [get_post_text] Length: 66
# <DEBUG-PrepareData> - [Post 229] ✔ Thêm post content, length: 66
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 230] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 33
# <DEBUG-PrepareData> - [Post 231] ✔ Thêm post content, length: 33
# <DEBUG-Entity> - [get_post_text] Length: 61
# <DEBUG-PrepareData> - [Post 232] ✔ Thêm post content, length: 61
# <DEBUG-Entity> - [get_post_text] Length: 81
# <DEBUG-PrepareData> - [Post 233] ✔ Thêm post content, length: 81
# <DEBUG-Entity> - [get_post_text] Length: 18
# <DEBUG-PrepareData> - [Post 234] ✔ Thêm post content, length: 18
# <DEBUG-Entity> - [get_post_text] Length: 71
# <DEBUG-PrepareData> - [Post 235] ✔ Thêm post content, length: 71
# <DEBUG-Entity> - [get_post_text] Length: 60
# <DEBUG-PrepareData> - [Post 236] ✔ Thêm post content, length: 60
# <DEBUG-Entity> - [get_post_text] Length: 62
# <DEBUG-PrepareData> - [Post 237] ✔ Thêm post content, length: 62
# <DEBUG-Entity> - [get_post_text] Length: 65
# <DEBUG-PrepareData> - [Post 238] ✔ Thêm post content, length: 65
# <DEBUG-Entity> - [get_post_text] Length: 40
# <DEBUG-PrepareData> - [Post 239] ✔ Thêm post content, length: 40
# <DEBUG-Entity> - [get_post_text] Length: 131
# <DEBUG-PrepareData> - [Post 240] ✔ Thêm post content, length: 131
# <DEBUG-Entity> - [get_post_text] Length: 99
# <DEBUG-PrepareData> - [Post 241] ✔ Thêm post content, length: 99
# <DEBUG-Entity> - [get_post_text] Length: 34
# <DEBUG-PrepareData> - [Post 242] ✔ Thêm post content, length: 34
# <DEBUG-Entity> - [get_post_text] Length: 110
# <DEBUG-PrepareData> - [Post 243] ✔ Thêm post content, length: 110
# <DEBUG-Entity> - [get_post_text] Length: 86
# <DEBUG-PrepareData> - [Post 244] ✔ Thêm post content, length: 86
# <DEBUG-Entity> - [get_post_text] Length: 83
# <DEBUG-PrepareData> - [Post 245] ✔ Thêm post content, length: 83
# <DEBUG-Entity> - [get_post_text] Length: 43
# <DEBUG-PrepareData> - [Post 246] ✔ Thêm post content, length: 43
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 247] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 45
# <DEBUG-PrepareData> - [Post 248] ✔ Thêm post content, length: 45
# <DEBUG-Entity> - [get_post_text] Length: 76
# <DEBUG-PrepareData> - [Post 249] ✔ Thêm post content, length: 76
# <DEBUG-Entity> - [get_post_text] Length: 113
# <DEBUG-PrepareData> - [Post 250] ✔ Thêm post content, length: 113
# <DEBUG-Entity> - [get_post_text] Length: 86
# <DEBUG-PrepareData> - [Post 251] ✔ Thêm post content, length: 86
# <DEBUG-Entity> - [get_post_text] Length: 110
# <DEBUG-PrepareData> - [Post 252] ✔ Thêm post content, length: 110
# <DEBUG-Entity> - [get_post_text] Length: 81
# <DEBUG-PrepareData> - [Post 253] ✔ Thêm post content, length: 81
# <DEBUG-Entity> - [get_post_text] Length: 94
# <DEBUG-PrepareData> - [Post 254] ✔ Thêm post content, length: 94
# <DEBUG-Entity> - [get_post_text] Length: 31
# <DEBUG-PrepareData> - [Post 255] ✔ Thêm post content, length: 31
# <DEBUG-Entity> - [get_post_text] Length: 97
# <DEBUG-PrepareData> - [Post 256] ✔ Thêm post content, length: 97
# <DEBUG-Entity> - [get_post_text] Length: 64
# <DEBUG-PrepareData> - [Post 257] ✔ Thêm post content, length: 64
# <DEBUG-Entity> - [get_post_text] Length: 76
# <DEBUG-PrepareData> - [Post 258] ✔ Thêm post content, length: 76
# <DEBUG-Entity> - [get_post_text] Length: 46
# <DEBUG-PrepareData> - [Post 259] ✔ Thêm post content, length: 46
# <DEBUG-Entity> - [get_post_text] Length: 114
# <DEBUG-PrepareData> - [Post 260] ✔ Thêm post content, length: 114
# <DEBUG-Entity> - [get_post_text] Length: 40
# <DEBUG-PrepareData> - [Post 261] ✔ Thêm post content, length: 40
# <DEBUG-Entity> - [get_post_text] Length: 102
# <DEBUG-PrepareData> - [Post 262] ✔ Thêm post content, length: 102
# <DEBUG-Entity> - [get_post_text] Length: 37
# <DEBUG-PrepareData> - [Post 263] ✔ Thêm post content, length: 37
# <DEBUG-Entity> - [get_post_text] Length: 88
# <DEBUG-PrepareData> - [Post 264] ✔ Thêm post content, length: 88
# <DEBUG-Entity> - [get_post_text] Length: 77
# <DEBUG-PrepareData> - [Post 265] ✔ Thêm post content, length: 77
# <DEBUG-Entity> - [get_post_text] Length: 97
# <DEBUG-PrepareData> - [Post 266] ✔ Thêm post content, length: 97
# <DEBUG-Entity> - [get_post_text] Length: 122
# <DEBUG-PrepareData> - [Post 267] ✔ Thêm post content, length: 122
# <DEBUG-Entity> - [get_post_text] Length: 93
# <DEBUG-PrepareData> - [Post 268] ✔ Thêm post content, length: 93
# <DEBUG-Entity> - [get_post_text] Length: 43
# <DEBUG-PrepareData> - [Post 269] ✔ Thêm post content, length: 43
# <DEBUG-Entity> - [get_post_text] Length: 33
# <DEBUG-PrepareData> - [Post 270] ✔ Thêm post content, length: 33
# <DEBUG-Entity> - [get_post_text] Length: 107
# <DEBUG-PrepareData> - [Post 271] ✔ Thêm post content, length: 107
# <DEBUG-Entity> - [get_post_text] Length: 87
# <DEBUG-PrepareData> - [Post 272] ✔ Thêm post content, length: 87
# <DEBUG-Entity> - [get_post_text] Length: 95
# <DEBUG-PrepareData> - [Post 273] ✔ Thêm post content, length: 95
# <DEBUG-Entity> - [get_post_text] Length: 81
# <DEBUG-PrepareData> - [Post 274] ✔ Thêm post content, length: 81
# <DEBUG-Entity> - [get_post_text] Length: 86
# <DEBUG-PrepareData> - [Post 275] ✔ Thêm post content, length: 86
# <DEBUG-Entity> - [get_post_text] Length: 100
# <DEBUG-PrepareData> - [Post 276] ✔ Thêm post content, length: 100
# <DEBUG-Entity> - [get_post_text] Length: 135
# <DEBUG-PrepareData> - [Post 277] ✔ Thêm post content, length: 135
# <DEBUG-Entity> - [get_post_text] Length: 61
# <DEBUG-PrepareData> - [Post 278] ✔ Thêm post content, length: 61
# <DEBUG-Entity> - [get_post_text] Length: 82
# <DEBUG-PrepareData> - [Post 279] ✔ Thêm post content, length: 82
# <DEBUG-Entity> - [get_post_text] Length: 37
# <DEBUG-PrepareData> - [Post 280] ✔ Thêm post content, length: 37
# <DEBUG-Entity> - [get_post_text] Length: 135
# <DEBUG-PrepareData> - [Post 281] ✔ Thêm post content, length: 135
# <DEBUG-Entity> - [get_post_text] Length: 43
# <DEBUG-PrepareData> - [Post 282] ✔ Thêm post content, length: 43
# <DEBUG-Entity> - [get_post_text] Length: 97
# <DEBUG-PrepareData> - [Post 283] ✔ Thêm post content, length: 97
# <DEBUG-Entity> - [get_post_text] Length: 91
# <DEBUG-PrepareData> - [Post 284] ✔ Thêm post content, length: 91
# <DEBUG-Entity> - [get_post_text] Length: 34
# <DEBUG-PrepareData> - [Post 285] ✔ Thêm post content, length: 34
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 286] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 46
# <DEBUG-PrepareData> - [Post 287] ✔ Thêm post content, length: 46
# <DEBUG-Entity> - [get_post_text] Length: 78
# <DEBUG-PrepareData> - [Post 288] ✔ Thêm post content, length: 78
# <DEBUG-Entity> - [get_post_text] Length: 119
# <DEBUG-PrepareData> - [Post 289] ✔ Thêm post content, length: 119
# <DEBUG-Entity> - [get_post_text] Length: 34
# <DEBUG-PrepareData> - [Post 290] ✔ Thêm post content, length: 34
# <DEBUG-Entity> - [get_post_text] Length: 51
# <DEBUG-PrepareData> - [Post 291] ✔ Thêm post content, length: 51
# <DEBUG-Entity> - [get_post_text] Length: 22
# <DEBUG-PrepareData> - [Post 292] ✔ Thêm post content, length: 22
# <DEBUG-Entity> - [get_post_text] Length: 81
# <DEBUG-PrepareData> - [Post 293] ✔ Thêm post content, length: 81
# <DEBUG-Entity> - [get_post_text] Length: 68
# <DEBUG-PrepareData> - [Post 294] ✔ Thêm post content, length: 68
# <DEBUG-Entity> - [get_post_text] Length: 95
# <DEBUG-PrepareData> - [Post 295] ✔ Thêm post content, length: 95
# <DEBUG-Entity> - [get_post_text] Length: 72
# <DEBUG-PrepareData> - [Post 296] ✔ Thêm post content, length: 72
# <DEBUG-Entity> - [get_post_text] Length: 65
# <DEBUG-PrepareData> - [Post 297] ✔ Thêm post content, length: 65
# <DEBUG-Entity> - [get_post_text] Length: 31
# <DEBUG-PrepareData> - [Post 298] ✔ Thêm post content, length: 31
# <DEBUG-Entity> - [get_post_text] Length: 72
# <DEBUG-PrepareData> - [Post 299] ✔ Thêm post content, length: 72
# <DEBUG-Entity> - [get_post_text] Length: 48
# <DEBUG-PrepareData> - [Post 300] ✔ Thêm post content, length: 48
# <DEBUG-Entity> - [get_post_text] Length: 116
# <DEBUG-PrepareData> - [Post 301] ✔ Thêm post content, length: 116
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 302] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 89
# <DEBUG-PrepareData> - [Post 303] ✔ Thêm post content, length: 89
# <DEBUG-Entity> - [get_post_text] Length: 39
# <DEBUG-PrepareData> - [Post 304] ✔ Thêm post content, length: 39
# <DEBUG-Entity> - [get_post_text] Length: 46
# <DEBUG-PrepareData> - [Post 305] ✔ Thêm post content, length: 46
# <DEBUG-Entity> - [get_post_text] Length: 99
# <DEBUG-PrepareData> - [Post 306] ✔ Thêm post content, length: 99
# <DEBUG-Entity> - [get_post_text] Length: 44
# <DEBUG-PrepareData> - [Post 307] ✔ Thêm post content, length: 44
# <DEBUG-Entity> - [get_post_text] Length: 72
# <DEBUG-PrepareData> - [Post 308] ✔ Thêm post content, length: 72
# <DEBUG-Entity> - [get_post_text] Length: 121
# <DEBUG-PrepareData> - [Post 309] ✔ Thêm post content, length: 121
# <DEBUG-Entity> - [get_post_text] Length: 85
# <DEBUG-PrepareData> - [Post 310] ✔ Thêm post content, length: 85
# <DEBUG-Entity> - [get_post_text] Length: 23
# <DEBUG-PrepareData> - [Post 311] ✔ Thêm post content, length: 23
# <DEBUG-Entity> - [get_post_text] Length: 97
# <DEBUG-PrepareData> - [Post 312] ✔ Thêm post content, length: 97
# <DEBUG-Entity> - [get_post_text] Length: 106
# <DEBUG-PrepareData> - [Post 313] ✔ Thêm post content, length: 106
# <DEBUG-Entity> - [get_post_text] Length: 17
# <DEBUG-PrepareData> - [Post 314] ✔ Thêm post content, length: 17
# <DEBUG-Entity> - [get_post_text] Length: 61
# <DEBUG-PrepareData> - [Post 315] ✔ Thêm post content, length: 61
# <DEBUG-Entity> - [get_post_text] Length: 51
# <DEBUG-PrepareData> - [Post 316] ✔ Thêm post content, length: 51
# <DEBUG-Entity> - [get_post_text] Length: 65
# <DEBUG-PrepareData> - [Post 317] ✔ Thêm post content, length: 65
# <DEBUG-Entity> - [get_post_text] Length: 80
# <DEBUG-PrepareData> - [Post 318] ✔ Thêm post content, length: 80
# <DEBUG-Entity> - [get_post_text] Length: 93
# <DEBUG-PrepareData> - [Post 319] ✔ Thêm post content, length: 93
# <DEBUG-Entity> - [get_post_text] Length: 108
# <DEBUG-PrepareData> - [Post 320] ✔ Thêm post content, length: 108
# <DEBUG-Entity> - [get_post_text] Length: 92
# <DEBUG-PrepareData> - [Post 321] ✔ Thêm post content, length: 92
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 322] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 93
# <DEBUG-PrepareData> - [Post 323] ✔ Thêm post content, length: 93
# <DEBUG-Entity> - [get_post_text] Length: 77
# <DEBUG-PrepareData> - [Post 324] ✔ Thêm post content, length: 77
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 325] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 126
# <DEBUG-PrepareData> - [Post 326] ✔ Thêm post content, length: 126
# <DEBUG-Entity> - [get_post_text] Length: 91
# <DEBUG-PrepareData> - [Post 327] ✔ Thêm post content, length: 91
# <DEBUG-Entity> - [get_post_text] Length: 106
# <DEBUG-PrepareData> - [Post 328] ✔ Thêm post content, length: 106
# <DEBUG-Entity> - [get_post_text] Length: 40
# <DEBUG-PrepareData> - [Post 329] ✔ Thêm post content, length: 40
# <DEBUG-Entity> - [get_post_text] Length: 68
# <DEBUG-PrepareData> - [Post 330] ✔ Thêm post content, length: 68
# <DEBUG-Entity> - [get_post_text] Length: 47
# <DEBUG-PrepareData> - [Post 331] ✔ Thêm post content, length: 47
# <DEBUG-Entity> - [get_post_text] Length: 96
# <DEBUG-PrepareData> - [Post 332] ✔ Thêm post content, length: 96
# <DEBUG-Entity> - [get_post_text] Length: 78
# <DEBUG-PrepareData> - [Post 333] ✔ Thêm post content, length: 78
# <DEBUG-Entity> - [get_post_text] Length: 47
# <DEBUG-PrepareData> - [Post 334] ✔ Thêm post content, length: 47
# <DEBUG-Entity> - [get_post_text] Length: 90
# <DEBUG-PrepareData> - [Post 335] ✔ Thêm post content, length: 90
# <DEBUG-Entity> - [get_post_text] Length: 38
# <DEBUG-PrepareData> - [Post 336] ✔ Thêm post content, length: 38
# <DEBUG-Entity> - [get_post_text] Length: 55
# <DEBUG-PrepareData> - [Post 337] ✔ Thêm post content, length: 55
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 338] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 27
# <DEBUG-PrepareData> - [Post 339] ✔ Thêm post content, length: 27
# <DEBUG-Entity> - [get_post_text] Length: 47
# <DEBUG-PrepareData> - [Post 340] ✔ Thêm post content, length: 47
# <DEBUG-Entity> - [get_post_text] Length: 67
# <DEBUG-PrepareData> - [Post 341] ✔ Thêm post content, length: 67
# <DEBUG-Entity> - [get_post_text] Length: 115
# <DEBUG-PrepareData> - [Post 342] ✔ Thêm post content, length: 115
# <DEBUG-Entity> - [get_post_text] Length: 60
# <DEBUG-PrepareData> - [Post 343] ✔ Thêm post content, length: 60
# <DEBUG-Entity> - [get_post_text] Length: 14
# <DEBUG-PrepareData> - [Post 344] ✔ Thêm post content, length: 14
# <DEBUG-Entity> - [get_post_text] Length: 84
# <DEBUG-PrepareData> - [Post 345] ✔ Thêm post content, length: 84
# <DEBUG-Entity> - [get_post_text] Length: 407
# <DEBUG-PrepareData> - [Post 346] ✔ Thêm post content, length: 407
# <DEBUG-Entity> - [get_post_text] Length: 1302
# <DEBUG-PrepareData> - [Post 347] ✔ Thêm post content, length: 1302
# <DEBUG-Entity> - [get_post_text] Length: 147
# <DEBUG-PrepareData> - [Post 348] ✔ Thêm post content, length: 147
# <DEBUG-Entity> - [get_post_text] Length: 670
# <DEBUG-PrepareData> - [Post 349] ✔ Thêm post content, length: 670
# <DEBUG-Entity> - [get_post_text] Length: 1272
# <DEBUG-PrepareData> - [Post 350] ✔ Thêm post content, length: 1272
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 351] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 433
# <DEBUG-PrepareData> - [Post 352] ✔ Thêm post content, length: 433
# <DEBUG-Entity> - [get_post_text] Length: 1244
# <DEBUG-PrepareData> - [Post 353] ✔ Thêm post content, length: 1244
# <DEBUG-Entity> - [get_post_text] Length: 413
# <DEBUG-PrepareData> - [Post 354] ✔ Thêm post content, length: 413
# <DEBUG-Entity> - [get_post_text] Length: 171
# <DEBUG-PrepareData> - [Post 355] ✔ Thêm post content, length: 171
# <DEBUG-Entity> - [get_post_text] Length: 82
# <DEBUG-PrepareData> - [Post 356] ✔ Thêm post content, length: 82
# <DEBUG-Entity> - [get_post_text] Length: 183
# <DEBUG-PrepareData> - [Post 357] ✔ Thêm post content, length: 183
# <DEBUG-Entity> - [get_post_text] Length: 458
# <DEBUG-PrepareData> - [Post 358] ✔ Thêm post content, length: 458
# <DEBUG-Entity> - [get_post_text] Length: 209
# <DEBUG-PrepareData> - [Post 359] ✔ Thêm post content, length: 209
# <DEBUG-Entity> - [get_post_text] Length: 449
# <DEBUG-PrepareData> - [Post 360] ✔ Thêm post content, length: 449
# <DEBUG-Entity> - [get_post_text] Length: 1347
# <DEBUG-PrepareData> - [Post 361] ✔ Thêm post content, length: 1347
# <DEBUG-Entity> - [get_post_text] Length: 664
# <DEBUG-PrepareData> - [Post 362] ✔ Thêm post content, length: 664
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 363] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 32
# <DEBUG-PrepareData> - [Post 364] ✔ Thêm post content, length: 32
# <DEBUG-Entity> - [get_post_text] Length: 37
# <DEBUG-PrepareData> - [Post 365] ✔ Thêm post content, length: 37
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 366] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 101
# <DEBUG-PrepareData> - [Post 367] ✔ Thêm post content, length: 101
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 368] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 269
# <DEBUG-PrepareData> - [Post 369] ✔ Thêm post content, length: 269
# <DEBUG-Entity> - [get_post_text] Length: 596
# <DEBUG-PrepareData> - [Post 370] ✔ Thêm post content, length: 596
# <DEBUG-Entity> - [get_post_text] Length: 218
# <DEBUG-PrepareData> - [Post 371] ✔ Thêm post content, length: 218
# <DEBUG-Entity> - [get_post_text] Length: 102
# <DEBUG-PrepareData> - [Post 372] ✔ Thêm post content, length: 102
# <DEBUG-Entity> - [get_post_text] Length: 585
# <DEBUG-PrepareData> - [Post 373] ✔ Thêm post content, length: 585
# <DEBUG-Entity> - [get_post_text] Length: 208
# <DEBUG-PrepareData> - [Post 374] ✔ Thêm post content, length: 208
# <DEBUG-Entity> - [get_post_text] Length: 100
# <DEBUG-PrepareData> - [Post 375] ✔ Thêm post content, length: 100
# <DEBUG-Entity> - [get_post_text] Length: 317
# <DEBUG-PrepareData> - [Post 376] ✔ Thêm post content, length: 317
# <DEBUG-Entity> - [get_post_text] Length: 57
# <DEBUG-PrepareData> - [Post 377] ✔ Thêm post content, length: 57
# <DEBUG-Entity> - [get_post_text] Length: 794
# <DEBUG-PrepareData> - [Post 378] ✔ Thêm post content, length: 794
# <DEBUG-Entity> - [get_post_text] Length: 1691
# <DEBUG-PrepareData> - [Post 379] ✔ Thêm post content, length: 1691
# <DEBUG-Entity> - [get_post_text] Length: 338
# <DEBUG-PrepareData> - [Post 380] ✔ Thêm post content, length: 338
# <DEBUG-Entity> - [get_post_text] Length: 425
# <DEBUG-PrepareData> - [Post 381] ✔ Thêm post content, length: 425
# <DEBUG-Entity> - [get_post_text] Length: 380
# <DEBUG-PrepareData> - [Post 382] ✔ Thêm post content, length: 380
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 383] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 162
# <DEBUG-PrepareData> - [Post 384] ✔ Thêm post content, length: 162
# <DEBUG-Entity> - [get_post_text] Length: 374
# <DEBUG-PrepareData> - [Post 385] ✔ Thêm post content, length: 374
# <DEBUG-Entity> - [get_post_text] Length: 993
# <DEBUG-PrepareData> - [Post 386] ✔ Thêm post content, length: 993
# <DEBUG-Entity> - [get_post_text] Length: 29
# <DEBUG-PrepareData> - [Post 387] ✔ Thêm post content, length: 29
# <DEBUG-Entity> - [get_post_text] Length: 456
# <DEBUG-PrepareData> - [Post 388] ✔ Thêm post content, length: 456
# <DEBUG-Entity> - [get_post_text] Length: 864
# <DEBUG-PrepareData> - [Post 389] ✔ Thêm post content, length: 864
# <DEBUG-Entity> - [get_post_text] Length: 77
# <DEBUG-PrepareData> - [Post 390] ✔ Thêm post content, length: 77
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 391] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 1543
# <DEBUG-PrepareData> - [Post 392] ✔ Thêm post content, length: 1543
# <DEBUG-Entity> - [get_post_text] Length: 167
# <DEBUG-PrepareData> - [Post 393] ✔ Thêm post content, length: 167
# <DEBUG-Entity> - [get_post_text] Length: 220
# <DEBUG-PrepareData> - [Post 394] ✔ Thêm post content, length: 220
# <DEBUG-Entity> - [get_post_text] Length: 80
# <DEBUG-PrepareData> - [Post 395] ✔ Thêm post content, length: 80
# <DEBUG-Entity> - [get_post_text] Length: 298
# <DEBUG-PrepareData> - [Post 396] ✔ Thêm post content, length: 298
# <DEBUG-Entity> - [get_post_text] Length: 314
# <DEBUG-PrepareData> - [Post 397] ✔ Thêm post content, length: 314
# <DEBUG-Entity> - [get_post_text] Length: 640
# <DEBUG-PrepareData> - [Post 398] ✔ Thêm post content, length: 640
# <DEBUG-Entity> - [get_post_text] Length: 202
# <DEBUG-PrepareData> - [Post 399] ✔ Thêm post content, length: 202
# <DEBUG-Entity> - [get_post_text] Length: 18
# <DEBUG-PrepareData> - [Post 400] ✔ Thêm post content, length: 18
# <DEBUG-Entity> - [get_post_text] Length: 185
# <DEBUG-PrepareData> - [Post 401] ✔ Thêm post content, length: 185
# <DEBUG-Entity> - [get_post_text] Length: 33
# <DEBUG-PrepareData> - [Post 402] ✔ Thêm post content, length: 33
# <DEBUG-Entity> - [get_post_text] Length: 75
# <DEBUG-PrepareData> - [Post 403] ✔ Thêm post content, length: 75
# <DEBUG-Entity> - [get_post_text] Length: 108
# <DEBUG-PrepareData> - [Post 404] ✔ Thêm post content, length: 108
# <DEBUG-Entity> - [get_post_text] Length: 759
# <DEBUG-PrepareData> - [Post 405] ✔ Thêm post content, length: 759
# <DEBUG-Entity> - [get_post_text] Length: 363
# <DEBUG-PrepareData> - [Post 406] ✔ Thêm post content, length: 363
# <DEBUG-Entity> - [get_post_text] Length: 1001
# <DEBUG-PrepareData> - [Post 407] ✔ Thêm post content, length: 1001
# <DEBUG-Entity> - [get_post_text] Length: 452
# <DEBUG-PrepareData> - [Post 408] ✔ Thêm post content, length: 452
# <DEBUG-Entity> - [get_post_text] Length: 795
# <DEBUG-PrepareData> - [Post 409] ✔ Thêm post content, length: 795
# <DEBUG-Entity> - [get_post_text] Length: 967
# <DEBUG-PrepareData> - [Post 410] ✔ Thêm post content, length: 967
# <DEBUG-Entity> - [get_post_text] Length: 138
# <DEBUG-PrepareData> - [Post 411] ✔ Thêm post content, length: 138
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 412] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 39
# <DEBUG-PrepareData> - [Post 413] ✔ Thêm post content, length: 39
# <DEBUG-Entity> - [get_post_text] Length: 118
# <DEBUG-PrepareData> - [Post 414] ✔ Thêm post content, length: 118
# <DEBUG-Entity> - [get_post_text] Length: 143
# <DEBUG-PrepareData> - [Post 415] ✔ Thêm post content, length: 143
# <DEBUG-Entity> - [get_post_text] Length: 30
# <DEBUG-PrepareData> - [Post 416] ✔ Thêm post content, length: 30
# <DEBUG-Entity> - [get_post_text] Length: 1260
# <DEBUG-PrepareData> - [Post 417] ✔ Thêm post content, length: 1260
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 418] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 127
# <DEBUG-PrepareData> - [Post 419] ✔ Thêm post content, length: 127
# <DEBUG-Entity> - [get_post_text] Length: 85
# <DEBUG-PrepareData> - [Post 420] ✔ Thêm post content, length: 85
# <DEBUG-Entity> - [get_post_text] Length: 119
# <DEBUG-PrepareData> - [Post 421] ✔ Thêm post content, length: 119
# <DEBUG-Entity> - [get_post_text] Length: 709
# <DEBUG-PrepareData> - [Post 422] ✔ Thêm post content, length: 709
# <DEBUG-Entity> - [get_post_text] Length: 38
# <DEBUG-PrepareData> - [Post 423] ✔ Thêm post content, length: 38
# <DEBUG-Entity> - [get_post_text] Length: 256
# <DEBUG-PrepareData> - [Post 424] ✔ Thêm post content, length: 256
# <DEBUG-Entity> - [get_post_text] Length: 77
# <DEBUG-PrepareData> - [Post 425] ✔ Thêm post content, length: 77
# <DEBUG-Entity> - [get_post_text] Length: 766
# <DEBUG-PrepareData> - [Post 426] ✔ Thêm post content, length: 766
# <DEBUG-Entity> - [get_post_text] Length: 560
# <DEBUG-PrepareData> - [Post 427] ✔ Thêm post content, length: 560
# <DEBUG-Entity> - [get_post_text] Length: 95
# <DEBUG-PrepareData> - [Post 428] ✔ Thêm post content, length: 95
# <DEBUG-Entity> - [get_post_text] Length: 774
# <DEBUG-PrepareData> - [Post 429] ✔ Thêm post content, length: 774
# <DEBUG-Entity> - [get_post_text] Length: 499
# <DEBUG-PrepareData> - [Post 430] ✔ Thêm post content, length: 499
# <DEBUG-Entity> - [get_post_text] Length: 336
# <DEBUG-PrepareData> - [Post 431] ✔ Thêm post content, length: 336
# <DEBUG-Entity> - [get_post_text] Length: 155
# <DEBUG-PrepareData> - [Post 432] ✔ Thêm post content, length: 155
# <DEBUG-Entity> - [get_post_text] Length: 25
# <DEBUG-PrepareData> - [Post 433] ✔ Thêm post content, length: 25
# <DEBUG-Entity> - [get_post_text] Length: 66
# <DEBUG-PrepareData> - [Post 434] ✔ Thêm post content, length: 66
# <DEBUG-Entity> - [get_post_text] Length: 95
# <DEBUG-PrepareData> - [Post 435] ✔ Thêm post content, length: 95
# <DEBUG-Entity> - [get_post_text] Length: 452
# ...
# <DEBUG-PrepareData> - [Post 711] ✔ Thêm post content, length: 96
# <DEBUG-Entity> - [get_post_text] Length: 140
# <DEBUG-PrepareData> - [Post 712] ✔ Thêm post content, length: 140
# <DEBUG-Entity> - [get_post_text] Length: 29
# <DEBUG-PrepareData> - [Post 713] ✔ Thêm post content, length: 29
# <DEBUG-Entity> - [get_post_text] Length: 36
# <DEBUG-PrepareData> - [Post 714] ✔ Thêm post content, length: 36
# <DEBUG-Entity> - [get_post_text] Length: 215
# <DEBUG-PrepareData> - [Post 715] ✔ Thêm post content, length: 215
# <DEBUG-Entity> - [get_post_text] Length: 64
# <DEBUG-PrepareData> - [Post 716] ✔ Thêm post content, length: 64
# <DEBUG-Entity> - [get_post_text] Length: 963
# <DEBUG-PrepareData> - [Post 717] ✔ Thêm post content, length: 963
# <DEBUG-Entity> - [get_post_text] Length: 622
# <DEBUG-PrepareData> - [Post 718] ✔ Thêm post content, length: 622
# <DEBUG-Entity> - [get_post_text] Length: 52
# <DEBUG-PrepareData> - [Post 719] ✔ Thêm post content, length: 52
# <DEBUG-Entity> - [get_post_text] Length: 135
# <DEBUG-PrepareData> - [Post 720] ✔ Thêm post content, length: 135
# <DEBUG-Entity> - [get_post_text] Length: 153
# <DEBUG-PrepareData> - [Post 721] ✔ Thêm post content, length: 153
# <DEBUG-Entity> - [get_post_text] Length: 166
# <DEBUG-PrepareData> - [Post 722] ✔ Thêm post content, length: 166
# <DEBUG-Entity> - [get_post_text] Length: 150
# <DEBUG-PrepareData> - [Post 723] ✔ Thêm post content, length: 150
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 724] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 49
# <DEBUG-PrepareData> - [Post 725] ✔ Thêm post content, length: 49
# <DEBUG-Entity> - [get_post_text] Length: 99
# <DEBUG-PrepareData> - [Post 726] ✔ Thêm post content, length: 99
# <DEBUG-Entity> - [get_post_text] Length: 51
# <DEBUG-PrepareData> - [Post 727] ✔ Thêm post content, length: 51
# <DEBUG-Entity> - [get_post_text] Length: 52
# <DEBUG-PrepareData> - [Post 728] ✔ Thêm post content, length: 52
# <DEBUG-Entity> - [get_post_text] Length: 698
# <DEBUG-PrepareData> - [Post 729] ✔ Thêm post content, length: 698
# <DEBUG-Entity> - [get_post_text] Length: 137
# <DEBUG-PrepareData> - [Post 730] ✔ Thêm post content, length: 137
# <DEBUG-Entity> - [get_post_text] Length: 193
# <DEBUG-PrepareData> - [Post 731] ✔ Thêm post content, length: 193
# <DEBUG-Entity> - [get_post_text] Length: 179
# <DEBUG-PrepareData> - [Post 732] ✔ Thêm post content, length: 179
# <DEBUG-Entity> - [get_post_text] Length: 1194
# <DEBUG-PrepareData> - [Post 733] ✔ Thêm post content, length: 1194
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 734] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 117
# <DEBUG-PrepareData> - [Post 735] ✔ Thêm post content, length: 117
# <DEBUG-Entity> - [get_post_text] Length: 246
# <DEBUG-PrepareData> - [Post 736] ✔ Thêm post content, length: 246
# <DEBUG-Entity> - [get_post_text] Length: 180
# <DEBUG-PrepareData> - [Post 737] ✔ Thêm post content, length: 180
# <DEBUG-Entity> - [get_post_text] Length: 128
# <DEBUG-PrepareData> - [Post 738] ✔ Thêm post content, length: 128
# <DEBUG-Entity> - [get_post_text] Length: 1095
# <DEBUG-PrepareData> - [Post 739] ✔ Thêm post content, length: 1095
# <DEBUG-Entity> - [get_post_text] Length: 141
# <DEBUG-PrepareData> - [Post 740] ✔ Thêm post content, length: 141
# <DEBUG-Entity> - [get_post_text] Length: 47
# <DEBUG-PrepareData> - [Post 741] ✔ Thêm post content, length: 47
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 742] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 786
# <DEBUG-PrepareData> - [Post 743] ✔ Thêm post content, length: 786
# <DEBUG-Entity> - [get_post_text] Length: 94
# <DEBUG-PrepareData> - [Post 744] ✔ Thêm post content, length: 94
# <DEBUG-Entity> - [get_post_text] Length: 67
# <DEBUG-PrepareData> - [Post 745] ✔ Thêm post content, length: 67
# <DEBUG-Entity> - [get_post_text] Length: 189
# <DEBUG-PrepareData> - [Post 746] ✔ Thêm post content, length: 189
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 747] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 142
# <DEBUG-PrepareData> - [Post 748] ✔ Thêm post content, length: 142
# <DEBUG-Entity> - [get_post_text] Length: 76
# <DEBUG-PrepareData> - [Post 749] ✔ Thêm post content, length: 76
# <DEBUG-Entity> - [get_post_text] Length: 77
# <DEBUG-PrepareData> - [Post 750] ✔ Thêm post content, length: 77
# <DEBUG-Entity> - [get_post_text] Length: 513
# <DEBUG-PrepareData> - [Post 751] ✔ Thêm post content, length: 513
# <DEBUG-Entity> - [get_post_text] Length: 201
# <DEBUG-PrepareData> - [Post 752] ✔ Thêm post content, length: 201
# <DEBUG-Entity> - [get_post_text] Length: 52
# <DEBUG-PrepareData> - [Post 753] ✔ Thêm post content, length: 52
# <DEBUG-Entity> - [get_post_text] Length: 38
# <DEBUG-PrepareData> - [Post 754] ✔ Thêm post content, length: 38
# <DEBUG-Entity> - [get_post_text] Length: 55
# <DEBUG-PrepareData> - [Post 755] ✔ Thêm post content, length: 55
# <DEBUG-Entity> - [get_post_text] Length: 269
# <DEBUG-PrepareData> - [Post 756] ✔ Thêm post content, length: 269
# <DEBUG-Entity> - [get_post_text] Length: 66
# <DEBUG-PrepareData> - [Post 757] ✔ Thêm post content, length: 66
# <DEBUG-Entity> - [get_post_text] Length: 48
# <DEBUG-PrepareData> - [Post 758] ✔ Thêm post content, length: 48
# <DEBUG-Entity> - [get_post_text] Length: 129
# <DEBUG-PrepareData> - [Post 759] ✔ Thêm post content, length: 129
# <DEBUG-Entity> - [get_post_text] Length: 1124
# <DEBUG-PrepareData> - [Post 760] ✔ Thêm post content, length: 1124
# <DEBUG-Entity> - [get_post_text] Length: 135
# <DEBUG-PrepareData> - [Post 761] ✔ Thêm post content, length: 135
# <DEBUG-Entity> - [get_post_text] Length: 141
# <DEBUG-PrepareData> - [Post 762] ✔ Thêm post content, length: 141
# <DEBUG-Entity> - [get_post_text] Length: 1718
# <DEBUG-PrepareData> - [Post 763] ✔ Thêm post content, length: 1718
# <DEBUG-Entity> - [get_post_text] Length: 37
# <DEBUG-PrepareData> - [Post 764] ✔ Thêm post content, length: 37
# <DEBUG-Entity> - [get_post_text] Length: 147
# <DEBUG-PrepareData> - [Post 765] ✔ Thêm post content, length: 147
# <DEBUG-Entity> - [get_post_text] Length: 257
# <DEBUG-PrepareData> - [Post 766] ✔ Thêm post content, length: 257
# <DEBUG-Entity> - [get_post_text] Length: 58
# <DEBUG-PrepareData> - [Post 767] ✔ Thêm post content, length: 58
# <DEBUG-Entity> - [get_post_text] Length: 63
# <DEBUG-PrepareData> - [Post 768] ✔ Thêm post content, length: 63
# <DEBUG-Entity> - [get_post_text] Length: 74
# <DEBUG-PrepareData> - [Post 769] ✔ Thêm post content, length: 74
# <DEBUG-Entity> - [get_post_text] Length: 151
# <DEBUG-PrepareData> - [Post 770] ✔ Thêm post content, length: 151
# <DEBUG-Entity> - [get_post_text] Length: 174
# <DEBUG-PrepareData> - [Post 771] ✔ Thêm post content, length: 174
# <DEBUG-Entity> - [get_post_text] Length: 51
# <DEBUG-PrepareData> - [Post 772] ✔ Thêm post content, length: 51
# <DEBUG-Entity> - [get_post_text] Length: 232
# <DEBUG-PrepareData> - [Post 773] ✔ Thêm post content, length: 232
# <DEBUG-Entity> - [get_post_text] Length: 55
# <DEBUG-PrepareData> - [Post 774] ✔ Thêm post content, length: 55
# <DEBUG-Entity> - [get_post_text] Length: 81
# <DEBUG-PrepareData> - [Post 775] ✔ Thêm post content, length: 81
# <DEBUG-Entity> - [get_post_text] Length: 147
# <DEBUG-PrepareData> - [Post 776] ✔ Thêm post content, length: 147
# <DEBUG-Entity> - [get_post_text] Length: 45
# <DEBUG-PrepareData> - [Post 777] ✔ Thêm post content, length: 45
# <DEBUG-Entity> - [get_post_text] Length: 73
# <DEBUG-PrepareData> - [Post 778] ✔ Thêm post content, length: 73
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 779] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 77
# <DEBUG-PrepareData> - [Post 780] ✔ Thêm post content, length: 77
# <DEBUG-Entity> - [get_post_text] Length: 48
# <DEBUG-PrepareData> - [Post 781] ✔ Thêm post content, length: 48
# <DEBUG-Entity> - [get_post_text] Length: 174
# <DEBUG-PrepareData> - [Post 782] ✔ Thêm post content, length: 174
# <DEBUG-Entity> - [get_post_text] Length: 69
# <DEBUG-PrepareData> - [Post 783] ✔ Thêm post content, length: 69
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 784] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 76
# <DEBUG-PrepareData> - [Post 785] ✔ Thêm post content, length: 76
# <DEBUG-Entity> - [get_post_text] Length: 158
# <DEBUG-PrepareData> - [Post 786] ✔ Thêm post content, length: 158
# <DEBUG-Entity> - [get_post_text] Length: 56
# <DEBUG-PrepareData> - [Post 787] ✔ Thêm post content, length: 56
# <DEBUG-Entity> - [get_post_text] Length: 160
# <DEBUG-PrepareData> - [Post 788] ✔ Thêm post content, length: 160
# <DEBUG-Entity> - [get_post_text] Length: 141
# <DEBUG-PrepareData> - [Post 789] ✔ Thêm post content, length: 141
# <DEBUG-Entity> - [get_post_text] Length: 252
# <DEBUG-PrepareData> - [Post 790] ✔ Thêm post content, length: 252
# <DEBUG-Entity> - [get_post_text] Length: 63
# <DEBUG-PrepareData> - [Post 791] ✔ Thêm post content, length: 63
# <DEBUG-Entity> - [get_post_text] Length: 170
# <DEBUG-PrepareData> - [Post 792] ✔ Thêm post content, length: 170
# <DEBUG-Entity> - [get_post_text] Length: 58
# <DEBUG-PrepareData> - [Post 793] ✔ Thêm post content, length: 58
# <DEBUG-Entity> - [get_post_text] Length: 78
# <DEBUG-PrepareData> - [Post 794] ✔ Thêm post content, length: 78
# <DEBUG-Entity> - [get_post_text] Length: 166
# <DEBUG-PrepareData> - [Post 795] ✔ Thêm post content, length: 166
# <DEBUG-Entity> - [get_post_text] Length: 80
# <DEBUG-PrepareData> - [Post 796] ✔ Thêm post content, length: 80
# <DEBUG-Entity> - [get_post_text] Length: 979
# <DEBUG-PrepareData> - [Post 797] ✔ Thêm post content, length: 979
# <DEBUG-Entity> - [get_post_text] Length: 62
# <DEBUG-PrepareData> - [Post 798] ✔ Thêm post content, length: 62
# <DEBUG-Entity> - [get_post_text] Length: 1512
# <DEBUG-PrepareData> - [Post 799] ✔ Thêm post content, length: 1512
# <DEBUG-Entity> - [get_post_text] Length: 151
# <DEBUG-PrepareData> - [Post 800] ✔ Thêm post content, length: 151
# <DEBUG-Entity> - [get_post_text] Length: 143
# <DEBUG-PrepareData> - [Post 801] ✔ Thêm post content, length: 143
# <DEBUG-Entity> - [get_post_text] Length: 63
# <DEBUG-PrepareData> - [Post 802] ✔ Thêm post content, length: 63
# <DEBUG-Entity> - [get_post_text] Length: 605
# <DEBUG-PrepareData> - [Post 803] ✔ Thêm post content, length: 605
# <DEBUG-Entity> - [get_post_text] Length: 60
# <DEBUG-PrepareData> - [Post 804] ✔ Thêm post content, length: 60
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 805] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 1130
# <DEBUG-PrepareData> - [Post 806] ✔ Thêm post content, length: 1130
# <DEBUG-Entity> - [get_post_text] Length: 62
# <DEBUG-PrepareData> - [Post 807] ✔ Thêm post content, length: 62
# <DEBUG-Entity> - [get_post_text] Length: 52
# <DEBUG-PrepareData> - [Post 808] ✔ Thêm post content, length: 52
# <DEBUG-Entity> - [get_post_text] Length: 133
# <DEBUG-PrepareData> - [Post 809] ✔ Thêm post content, length: 133
# <DEBUG-Entity> - [get_post_text] Length: 177
# <DEBUG-PrepareData> - [Post 810] ✔ Thêm post content, length: 177
# <DEBUG-Entity> - [get_post_text] Length: 58
# <DEBUG-PrepareData> - [Post 811] ✔ Thêm post content, length: 58
# <DEBUG-Entity> - [get_post_text] Length: 86
# <DEBUG-PrepareData> - [Post 812] ✔ Thêm post content, length: 86
# <DEBUG-Entity> - [get_post_text] Length: 100
# <DEBUG-PrepareData> - [Post 813] ✔ Thêm post content, length: 100
# <DEBUG-Entity> - [get_post_text] Length: 169
# <DEBUG-PrepareData> - [Post 814] ✔ Thêm post content, length: 169
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 815] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 104
# <DEBUG-PrepareData> - [Post 816] ✔ Thêm post content, length: 104
# <DEBUG-Entity> - [get_post_text] Length: 242
# <DEBUG-PrepareData> - [Post 817] ✔ Thêm post content, length: 242
# <DEBUG-Entity> - [get_post_text] Length: 44
# <DEBUG-PrepareData> - [Post 818] ✔ Thêm post content, length: 44
# <DEBUG-Entity> - [get_post_text] Length: 50
# <DEBUG-PrepareData> - [Post 819] ✔ Thêm post content, length: 50
# <DEBUG-Entity> - [get_post_text] Length: 169
# <DEBUG-PrepareData> - [Post 820] ✔ Thêm post content, length: 169
# <DEBUG-Entity> - [get_post_text] Length: 68
# <DEBUG-PrepareData> - [Post 821] ✔ Thêm post content, length: 68
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 822] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 47
# <DEBUG-PrepareData> - [Post 823] ✔ Thêm post content, length: 47
# <DEBUG-Entity> - [get_post_text] Length: 64
# <DEBUG-PrepareData> - [Post 824] ✔ Thêm post content, length: 64
# <DEBUG-Entity> - [get_post_text] Length: 61
# <DEBUG-PrepareData> - [Post 825] ✔ Thêm post content, length: 61
# <DEBUG-Entity> - [get_post_text] Length: 205
# <DEBUG-PrepareData> - [Post 826] ✔ Thêm post content, length: 205
# <DEBUG-Entity> - [get_post_text] Length: 67
# <DEBUG-PrepareData> - [Post 827] ✔ Thêm post content, length: 67
# <DEBUG-Entity> - [get_post_text] Length: 61
# <DEBUG-PrepareData> - [Post 828] ✔ Thêm post content, length: 61
# <DEBUG-Entity> - [get_post_text] Length: 208
# <DEBUG-PrepareData> - [Post 829] ✔ Thêm post content, length: 208
# <DEBUG-Entity> - [get_post_text] Length: 167
# <DEBUG-PrepareData> - [Post 830] ✔ Thêm post content, length: 167
# <DEBUG-Entity> - [get_post_text] Length: 55
# <DEBUG-PrepareData> - [Post 831] ✔ Thêm post content, length: 55
# <DEBUG-Entity> - [get_post_text] Length: 80
# <DEBUG-PrepareData> - [Post 832] ✔ Thêm post content, length: 80
# <DEBUG-Entity> - [get_post_text] Length: 158
# <DEBUG-PrepareData> - [Post 833] ✔ Thêm post content, length: 158
# <DEBUG-Entity> - [get_post_text] Length: 84
# <DEBUG-PrepareData> - [Post 834] ✔ Thêm post content, length: 84
# <DEBUG-Entity> - [get_post_text] Length: 119
# <DEBUG-PrepareData> - [Post 835] ✔ Thêm post content, length: 119
# <DEBUG-Entity> - [get_post_text] Length: 64
# <DEBUG-PrepareData> - [Post 836] ✔ Thêm post content, length: 64
# <DEBUG-Entity> - [get_post_text] Length: 127
# <DEBUG-PrepareData> - [Post 837] ✔ Thêm post content, length: 127
# <DEBUG-Entity> - [get_post_text] Length: 2550
# <DEBUG-PrepareData> - [Post 838] ✔ Thêm post content, length: 2550
# <DEBUG-Entity> - [get_post_text] Length: 59
# <DEBUG-PrepareData> - [Post 839] ✔ Thêm post content, length: 59
# <DEBUG-Entity> - [get_post_text] Length: 199
# <DEBUG-PrepareData> - [Post 840] ✔ Thêm post content, length: 199
# <DEBUG-Entity> - [get_post_text] Length: 2079
# <DEBUG-PrepareData> - [Post 841] ✔ Thêm post content, length: 2079
# <DEBUG-Entity> - [get_post_text] Length: 484
# <DEBUG-PrepareData> - [Post 842] ✔ Thêm post content, length: 484
# <DEBUG-Entity> - [get_post_text] Length: 68
# <DEBUG-PrepareData> - [Post 843] ✔ Thêm post content, length: 68
# <DEBUG-Entity> - [get_post_text] Length: 72
# <DEBUG-PrepareData> - [Post 844] ✔ Thêm post content, length: 72
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 845] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 45
# <DEBUG-PrepareData> - [Post 846] ✔ Thêm post content, length: 45
# <DEBUG-Entity> - [get_post_text] Length: 49
# <DEBUG-PrepareData> - [Post 847] ✔ Thêm post content, length: 49
# <DEBUG-Entity> - [get_post_text] Length: 50
# <DEBUG-PrepareData> - [Post 848] ✔ Thêm post content, length: 50
# <DEBUG-Entity> - [get_post_text] Length: 44
# <DEBUG-PrepareData> - [Post 849] ✔ Thêm post content, length: 44
# <DEBUG-Entity> - [get_post_text] Length: 53
# <DEBUG-PrepareData> - [Post 850] ✔ Thêm post content, length: 53
# <DEBUG-Entity> - [get_post_text] Length: 120
# <DEBUG-PrepareData> - [Post 851] ✔ Thêm post content, length: 120
# <DEBUG-Entity> - [get_post_text] Length: 79
# <DEBUG-PrepareData> - [Post 852] ✔ Thêm post content, length: 79
# <DEBUG-Entity> - [get_post_text] Length: 122
# <DEBUG-PrepareData> - [Post 853] ✔ Thêm post content, length: 122
# <DEBUG-Entity> - [get_post_text] Length: 72
# <DEBUG-PrepareData> - [Post 854] ✔ Thêm post content, length: 72
# <DEBUG-Entity> - [get_post_text] Length: 86
# <DEBUG-PrepareData> - [Post 855] ✔ Thêm post content, length: 86
# <DEBUG-PrepareData> - [prepare_corpus_post_only_df] ✅ Tổng số dòng: 855

# %%
post_content.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/13897673.py in <cell line: 0>()
# ----> 1 post_content.csv
#
# NameError: name 'post_content' is not defined

# %%
data_file = "content_posts.csv"
Utils.write_csv(df, data_file)

# %%
ls
# Out:
# input/  lib/  working/
